# %% [markdown]
# ## Starting Off
#
# Message me one question you have about APIs. Any question at all

# %% [markdown]
# # Using APIs and JSON Data

# %% [markdown]
# ## Objectives
# You will be able to:
# * Make an API call to Yelp

# %% [markdown]
# ## Agenda
#
# * Build up an API Call
# * Look at the results

# %%
import requests
import json

# %% [markdown]
# For more information about the request package you can use the following resources:
#
# **Tutorial:** https://realpython.com/python-requests/
#
# **Package Documentation:** https://requests.readthedocs.io/en/master/

# %% [markdown]
# ![](quota.png)

# %% [markdown]
# Let's do a search of businesses on the Yelp API.

# %%
# set theurl and endpoint we want to hit
url =  'https://api.yelp.com/v3/businesses/search'

# %% [markdown]
# Now that you have an API key, let's enter set that information here so that we can do our searches. Once you have the `api_key` variable, place int in our header.

# %%
client_id = '-uqWDK-AroyJM7jqJ5zP8Q'
api_key = 'DyHgCLzELZZrIeI5pbvaXjz97CihKM-_aUVH3Ga8EYeTMLFmV59fm4VEO77af57qXjwGAjxIfYCODheuvhrw67YBnDwVI9kqWHs62sjL5HGzwXESA-HmL7twoZaPXnYx'

# %%
#from  keys  import  client_id, api_key

# %%
print(api_key)
# Out:
# DyHgCLzELZZrIeI5pbvaXjz97CihKM-_aUVH3Ga8EYeTMLFmV59fm4VEO77af57qXjwGAjxIfYCODheuvhrw67YBnDwVI9kqWHs62sjL5HGzwXESA-HmL7twoZaPXnYx

# %%
headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

# %% [markdown]
# We now need to determine our parameters we want to pass.
#
# You must give a specific search term, location and one other paramter to limit your search.
#
# Remember you can search the API documenation to find another parameter to limit your search.
# https://www.yelp.com/developers/documentation/v3/get_started

# %%
# what type of business do you want to search
term = 'Pizza'

#where do you want to perform this search
location = 'New Dorp'

# what is your other parameter you want to search against
radius = 2500

# %%
url_params = {
                "term": term.replace(' ', '+'),
                "location": location.replace(' ', '+'),
                "radius" : radius,
                "limit": 50
            }

# %%
url_params
# Out:
# {'term': 'Pizza', 'location': 'New+Dorp', 'radius': 2500, 'limit': 50}

# %% [markdown]
# Now that we have all of the parts necessary for an API call, let's put them together.

# %%
response = requests.get(url, headers = headers, params = url_params)

# %% [markdown]
# ## The Response
#
# The response of a GET request often has some valuable information, known as a payload, in the message body. Using the attributes and methods of Response, you can view the payload in a variety of different formats.
#
# To see the response’s content in bytes, you use `.content`
#
# You will often want to convert them into a string using a character encoding such as UTF-8. Response will do that for you when you access `.text`
#
# The response is actually serialized JSON content. To get a dictionary, you could take the str you retrieved from `.text` and deserialize it using `json.loads()`. However, a simpler way to accomplish this task is to use `.json()`:

# %%
response.text
# Out:
# '{"businesses": [{"id": "LlT5XLc88hFDcWiCKskasg", "alias": "pizzeria-giove-staten-island", "name": "Pizzeria Giove", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/w-Ne6LJLVLnmJlJJBazRsA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/pizzeria-giove-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q", "review_count": 307, "categories": [{"alias": "italian", "title": "Italian"}], "rating": 4.0, "coordinates": {"latitude": 40.57215, "longitude": -74.1131599}, "transactions": [], "price": "$$", "location": {"address1": "278 New Dorp Ln", "address2": "", "address3": "", "city": "Staten Island", "zip_code": "10306", "country": "US", "state": "NY", "display_address": ["278 New Dorp Ln", "Staten Island, NY 10306"]}, "phone": "+13472860635", "display_phone": "(347) 286-0635", "distance": 75.34648018324394}, {"id": "eendqrZ9Cp_JisaDtoBU4w", "alias": "bravo-pizza-staten-island", "name": "Bravo Pizza", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/98GIefvXOn22c6qrv3ebMQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/bravo-pizza-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q", "review_count": 11, "categories": [{"alias": "pizza", "title": "Pizza"}, {"alias": "sportsbars", "title": "Sports Bars"}], "rating": 3.5, "coordinates": {"latitude": 40.5701278126894, "longitude": -74.108795389156}, "transactions": [], "price": "$$", "location": {"address1": "413  New Dorp Ln", "address2": "", "address3": null, "city": "Staten Island", "zip_code": "10306", "country": "US", "state": "NY", "display_address": ["413  New Dorp Ln", "Staten Island, NY 10306"]}, "phone": "+17183171010", "display_phone": "(718) 317-1010", "distance": 384.43767528529156}, {"id": "-jdadX3fGXA2TDapnufYFA", "alias": "dough-by-licastri-staten-island", "name": "DOUGH By Licastri", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/eHIjhfgelm1nBhir7Rq_-w/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/dough-by-licastri-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q", "review_count": 131, "categories": [{"alias": "pizza", "title": "Pizza"}, {"alias": "sandwiches", "title": "Sandwiches"}], "rating": 4.5, "coordinates": {"latitude": 40.59391, "longitude": -74.09948}, "transactions": ["pickup", "delivery"], "price": "$$", "location": {"address1": "1456 Richmond Rd", "address2": null, "address3": "", "city": "Staten Island", "zip_code": "10304", "country": "US", "state": "NY", "display_address": ["1456 Richmond Rd", "Staten Island, NY 10304"]}, "phone": "+17186681600", "display_phone": "(718) 668-1600", "distance": 2744.5071665458286}, {"id": "2NBbuLr9JWEzfbvML83Dkg", "alias": "giacomos-pizzeria-staten-island", "name": "Giacomos Pizzeria", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/tUNTsQo16oggOlR_OpHejQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/giacomos-pizzeria-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q", "review_count": 34, "categories": [{"alias": "pizza", "title": "Pizza"}], "rating": 3.5, "coordinates": {"latitude": 40.57326, "longitude": -74.11522}, "transactions": ["pickup", "delivery"], "location": {"address1": "170 New Dorp Ln", "address2": "", "address3": null, "city": "Staten Island", "zip_code": "10306", "country": "US", "state": "NY", "display_address": ["170 New Dorp Ln", "Staten Island, NY 10306"]}, "phone": "+17186680490", "display_phone": "(718) 668-0490", "distance": 271.76136780900123}, {"id": "Chaq0plYdKIILsAfAFvwBA", "alias": "nunzios-pizzeria-and-restaurant-staten-island", "name": "Nunzio\'s Pizzeria & Restaurant", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/upT_UvNekVt8LQPckOVW ...

# %%
json.loads(response.text)
# Out:
# {'businesses': [{'id': 'LlT5XLc88hFDcWiCKskasg',
#    'alias': 'pizzeria-giove-staten-island',
#    'name': 'Pizzeria Giove',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/w-Ne6LJLVLnmJlJJBazRsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pizzeria-giove-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 307,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.57215, 'longitude': -74.1131599},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '278 New Dorp Ln',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['278 New Dorp Ln', 'Staten Island, NY 10306']},
#    'phone': '+13472860635',
#    'display_phone': '(347) 286-0635',
#    'distance': 75.34648018324394},
#   {'id': 'eendqrZ9Cp_JisaDtoBU4w',
#    'alias': 'bravo-pizza-staten-island',
#    'name': 'Bravo Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/98GIefvXOn22c6qrv3ebMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bravo-pizza-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 11,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.5701278126894,
#     'longitude': -74.108795389156},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '413  New Dorp Ln',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['413  New Dorp Ln', 'Staten Island, NY 10306']},
#    'phone': '+17183171010',
#    'display_phone': '(718) 317-1010',
#    'distance': 384.43767528529156},
#   {'id': '-jdadX3fGXA2TDapnufYFA',
#    'alias': 'dough-by-licastri-staten-island',
#    'name': 'DOUGH By Licastri',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eHIjhfgelm1nBhir7Rq_-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dough-by-licastri-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 131,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.59391, 'longitude': -74.09948},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1456 Richmond Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10304',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1456 Richmond Rd', 'Staten Island, NY 10304']},
#    'phone': '+17186681600',
#    'display_phone': '(718) 668-1600',
#    'distance': 2744.5071665458286},
#   {'id': '2NBbuLr9JWEzfbvML83Dkg',
#    'alias': 'giacomos-pizzeria-staten-island',
#    'name': 'Giacomos Pizzeria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tUNTsQo16oggOlR_OpHejQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/giacomos-pizzeria-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 34,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.57326, 'longitude': -74.11522},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '170 New Dorp Ln',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['170 New Dorp Ln', 'Staten Island, NY 10306']},
#    'phone': '+17186680490',
#    'display_phone': '(718) 668-0490',
#    'distance': 271.76136780900123},
#   {'id': 'Chaq0plYdKIILsAfAFvwBA',
#    'alias': 'nunzios-pizzeria-and-restaurant-staten-island',
#    'name': "Nunzio's Pizzeria & Restaurant",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/upT_UvNekVt8LQPckOVWQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nunzios-pizzeria-and-restaurant-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 109,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.57799, 'longitude': -74.10271},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '2155 Hylan Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2155 Hylan Blvd', 'Staten Island, NY 10306']},
#    'phone': '+17186679647',
#    'display_phone': '(718) 667-9647',
#    'distance': 1132.1659743860528},
#   {'id': 'U0HmnNv1wJL-dANj_Dq71A',
#    'alias': 'lees-tavern-staten-island',
#    'name': "Lee's Tavern",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XzJqQB18-UeZaeWrsHyyGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lees-tavern-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 498,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.588756, 'longitude': -74.095153},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '60 Hancock St',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10305',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['60 Hancock St', 'Staten Island, NY 10305']},
#    'phone': '+17186679749',
#    'display_phone': '(718) 667-9749',
#    'distance': 2443.1955234493444},
#   {'id': 'yWGdfTjzk0KDjrUpUan5vA',
#    'alias': 'prime-pizza-kitchen-staten-island',
#    'name': 'Prime Pizza Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_TimNJnhQIAwyYrQK59vEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/prime-pizza-kitchen-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 47,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.5853249350922,
#     'longitude': -74.0926520634632},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '1778 Hylan Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10305',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1778 Hylan Blvd', 'Staten Island, NY 10305']},
#    'phone': '+17183515000',
#    'display_phone': '(718) 351-5000',
#    'distance': 2308.715085845923},
#   {'id': '9JFO3le5_jl5_yaC4fKLbw',
#    'alias': 'restaurant-on-the-plaza-pizzeria-staten-island',
#    'name': 'Restaurant On the Plaza Pizzeria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QkT8bHcjs6sNdGP-GhAD0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/restaurant-on-the-plaza-pizzeria-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 20,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.57338, 'longitude': -74.11664},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '50 New Dorp Plz',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['50 New Dorp Plz', 'Staten Island, NY 10306']},
#    'phone': '+17186677170',
#    'display_phone': '(718) 667-7170',
#    'distance': 386.15973125965326},
#   {'id': '-m8hYUDP6howLkVkEzBGSg',
#    'alias': 'pronto-pizza-staten-island-3',
#    'name': 'Pronto Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_gkJFPtrnC6sxZ9mntUC0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pronto-pizza-staten-island-3?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 49,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.57147, 'longitude': -74.1111},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '337 New Dorp Ln',
#     'address2': None,
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['337 New Dorp Ln', 'Staten Island, NY 10306']},
#    'phone': '+17183512700',
#    'display_phone': '(718) 351-2700',
#    'distance': 157.99406266087638},
#   {'id': '461hss6jSwjN8FdiZgN6wA',
#    'alias': 'the-original-goodfellas-brick-oven-pizza-staten-island-2',
#    'name': "The Original Goodfella's Brick Oven Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6DQT6mdKn05HGmDapqlRgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-original-goodfellas-brick-oven-pizza-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 246,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.586785, 'longitude': -74.091438},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1718 Hylan Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10305',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1718 Hylan Blvd', 'Staten Island, NY 10305']},
#    'phone': '+17189872422',
#    'display_phone': '(718) 987-2422',
#    'distance': 2493.9961938672122},
#   {'id': 'iPLXtSD442PQXnlC5jAqbg',
#    'alias': 'cucina-fresca-staten-island-2',
#    'name': 'Cucina Fresca',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Q5W4Q6JvpSSe4CNInCywLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cucina-fresca-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 88,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.581292, 'longitude': -74.111488},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2110 Richmond Rd',
#     'address2': 'Ste 6',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2110 Richmond Rd',
#      'Ste 6',
#      'Staten Island, NY 10306']},
#    'phone': '+17186675152',
#    'display_phone': '(718) 667-5152',
#    'distance': 1119.0874410621886},
#   {'id': 'SNX8DPWkqhPDYnw2k0QUGA',
#    'alias': 'ny-family-pizza-staten-island',
#    'name': 'NY Family Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VGMMqzvV1j7SwFb9gsza_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ny-family-pizza-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 16,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.58329, 'longitude': -74.095077},
#    'transactions': [],
#    'location': {'address1': '1880 Hylan Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10305',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1880 Hylan Blvd', 'Staten Island, NY 10305']},
#    'phone': '+17189877000',
#    'display_phone': '(718) 987-7000',
#    'distance': 2005.4323725744332},
#   {'id': 'OBz9S_wgdXKxIX1CbU41Lw',
#    'alias': 'cuzzin-joes-pizza-staten-island',
#    'name': 'Cuzzin Joes Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2okReqJ2-fLzElfKVW7gww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cuzzin-joes-pizza-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 3,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.572232, 'longitude': -74.093347},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '572 Midland Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['572 Midland Ave', 'Staten Island, NY 10306']},
#    'phone': '+17183519333',
#    'display_phone': '(718) 351-9333',
#    'distance': 1660.9745970802119},
#   {'id': 'lnY_TfGOGeRs00tHIi0T1w',
#    'alias': 'via-napoli-staten-island-2',
#    'name': 'Via Napoli',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hRvF9v4cXbaxVVyvojYBjQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/via-napoli-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 68,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.56743, 'longitude': -74.11138},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '2626 Hylan Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2626 Hylan Blvd', 'Staten Island, NY 10306']},
#    'phone': '+17186678599',
#    'display_phone': '(718) 667-8599',
#    'distance': 462.2399838771992},
#   {'id': 'wvXF3ESpaU9ly_er_DEzxQ',
#    'alias': 'ambrosinos-pizzeria-staten-island',
#    'name': "Ambrosino's Pizzeria",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DtvBxYwRyuoFwr6376EqKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ambrosinos-pizzeria-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 35,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.564278, 'longitude': -74.133473},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '3161 Amboy Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3161 Amboy Rd', 'Staten Island, NY 10306']},
#    'phone': '+17189878800',
#    'display_phone': '(718) 987-8800',
#    'distance': 1904.8873603938653},
#   {'id': 'P2C2U2LRC-POjGClJMKr6A',
#    'alias': 'domenicos-pizza-staten-island-51',
#    'name': "Domenico's Pizza",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ARBdRD6drM4wdAFJkz3MQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/domenicos-pizza-staten-island-51?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 58,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.561036, 'longitude': -74.135384},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '3295 Amboy Rd',
#     'address2': 'Ste 3',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3295 Amboy Rd', 'Ste 3', 'Staten Island, NY 10306']},
#    'phone': '+17183512100',
#    'display_phone': '(718) 351-2100',
#    'distance': 2217.8109660697214},
#   {'id': 'GoODm3ptRYL964UeYbKPkQ',
#    'alias': 'justinos-pizzeria-staten-island',
#    'name': "Justino's Pizzeria",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Y_frBA2b-T7uga_3wAmrfg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/justinos-pizzeria-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 48,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.5649, 'longitude': -74.12772},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '89 Guyon Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['89 Guyon Ave', 'Staten Island, NY 10306']},
#    'phone': '+17186682020',
#    'display_phone': '(718) 668-2020',
#    'distance': 1439.7485565451568},
#   {'id': 'VAi8d2WDjjKN7saJ2rNRHg',
#    'alias': 'classic-pizza-staten-island-2',
#    'name': 'Classic Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zAkUlUzbEYob2_6PMpKjGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/classic-pizza-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 21,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.575512, 'longitude': -74.127824},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '3201 Richmond Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3201 Richmond Rd', 'Staten Island, NY 10306']},
#    'phone': '+17189872500',
#    'display_phone': '(718) 987-2500',
#    'distance': 1338.548091147004},
#   {'id': 'q4CBRjGixsHaK0Abm-byNw',
#    'alias': 'panino-rustico-staten-island-staten-island',
#    'name': 'Panino Rustico - Staten Island',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/V7jJEWJv1fbguORCb7GwuQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/panino-rustico-staten-island-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 91,
#    'categories': [{'alias': 'creperies', 'title': 'Creperies'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.58129, 'longitude': -74.11149},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2110 Richmond Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2110 Richmond Rd', 'Staten Island, NY 10306']},
#    'phone': '+17183510100',
#    'display_phone': '(718) 351-0100',
#    'distance': 1119.0874410621886},
#   {'id': 'lDz5EIOmtua_tl-UcY78wA',
#    'alias': 'sharkeys-square-pizza-staten-island',
#    'name': "Sharkey's Square Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LaqmQn2wE3W8oT74hNi7iA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sharkeys-square-pizza-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 48,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.5827865600586,
#     'longitude': -74.0960235595703},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '1910 Hylan Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10305',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1910 Hylan Blvd', 'Staten Island, NY 10305']},
#    'phone': '+17189794700',
#    'display_phone': '(718) 979-4700',
#    'distance': 1908.5896701189322},
#   {'id': 'pncElrotZZCTr_l1bWtB6w',
#    'alias': 'torino-cafe-staten-island-2',
#    'name': 'Torino Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/11ZcXncCmK4gJ8O4Y2mDyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/torino-cafe-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 16,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.58882, 'longitude': -74.1018},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1694 Richmond Rd',
#     'address2': None,
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10304',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1694 Richmond Rd', 'Staten Island, NY 10304']},
#    'phone': '+17183513100',
#    'display_phone': '(718) 351-3100',
#    'distance': 2147.9663213616604},
#   {'id': 'eMMF_kyHQIrX_An67wYcpA',
#    'alias': 'griffs-place-new-dorp-beach',
#    'name': "Griff's Place",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/I3ZxAUjOWHtRcE8p5PQ4SQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/griffs-place-new-dorp-beach?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 61,
#    'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.5656772, 'longitude': -74.100421},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '704 New Dorp Ln',
#     'address2': '',
#     'address3': '',
#     'city': 'New Dorp Beach',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['704 New Dorp Ln', 'New Dorp Beach, NY 10306']},
#    'phone': '+17186682645',
#    'display_phone': '(718) 668-2645',
#    'distance': 1232.371971624808},
#   {'id': 'KMLT72-bHysWDTqbzunhDw',
#    'alias': 'little-italy-gourmet-staten-island',
#    'name': 'Little Italy Gourmet',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/sBl_b4UGrno-QbUBhAwR4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-italy-gourmet-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 25,
#    'categories': [{'alias': 'intlgrocery', 'title': 'International Grocery'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.57489, 'longitude': -74.116065},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1375 N Railroad Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1375 N Railroad Ave', 'Staten Island, NY 10306']},
#    'phone': '+17189803663',
#    'display_phone': '(718) 980-3663',
#    'distance': 460.2778480603174},
#   {'id': 'lr0M6lCGZPzijNlHz3ZGsA',
#    'alias': 'kim-cooks-and-caters-staten-island',
#    'name': 'Kim Cooks & Caters',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/54vGCyMXlZdZ57eyEukkaA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kim-cooks-and-caters-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 16,
#    'categories': [{'alias': 'catering', 'title': 'Caterers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.579906, 'longitude': -74.109256},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '97 Lincoln Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['97 Lincoln Ave', 'Staten Island, NY 10306']},
#    'phone': '+12124252623',
#    'display_phone': '(212) 425-2623',
#    'distance': 992.3150623690841},
#   {'id': 'kE0nfIY9l_guZTo8AlfHeg',
#    'alias': 'fresh-twist-juicebar-and-cafe-staten-island',
#    'name': 'Fresh Twist juicebar & cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/eXWAVjrq57L89p2qU6kmow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fresh-twist-juicebar-and-cafe-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 58,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'empanadas', 'title': 'Empanadas'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.5753893, 'longitude': -74.1192837},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '10 New Dorp Ln',
#     'address2': None,
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['10 New Dorp Ln', 'Staten Island, NY 10306']},
#    'phone': '+19178301644',
#    'display_phone': '(917) 830-1644',
#    'distance': 719.9921010341428},
#   {'id': 'iXfgnXG-LKT5R0ZlUbSHlA',
#    'alias': 'papa-johns-pizza-staten-island-2',
#    'name': "Papa John's Pizza",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cRJxEZWBnTemsiXlzPfqBw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/papa-johns-pizza-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 15,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 1.5,
#    'coordinates': {'latitude': 40.577494, 'longitude': -74.103382},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '2175 Hyland Blvd.',
#     'address2': None,
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2175 Hyland Blvd.', 'Staten Island, NY 10306']},
#    'phone': '+17186673474',
#    'display_phone': '(718) 667-3474',
#    'distance': 1053.607211325036},
#   {'id': '1Xfz59j6iyGH6Z-GtSJblA',
#    'alias': 'how-greek-it-is-staten-island',
#    'name': 'How Greek It Is',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SkP80p8TRthZr2F3zBW6Fg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/how-greek-it-is-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 126,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.5760758, 'longitude': -74.1033838},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2224 Hylan Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2224 Hylan Blvd', 'Staten Island, NY 10306']},
#    'phone': '+17182733200',
#    'display_phone': '(718) 273-3200',
#    'distance': 960.7326315037509},
#   {'id': 'SNTBdiEi55Zvt3qa4AAEJg',
#    'alias': 'sakana-sushi-and-hibachi-steakhouse-staten-island',
#    'name': 'Sakana Sushi & Hibachi Steakhouse',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2A3iBAhvVfunyW8L8KmZGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sakana-sushi-and-hibachi-steakhouse-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 13,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.589737938998,
#     'longitude': -74.1013584556552},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1657 Richmond Rd',
#     'address2': None,
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10304',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1657 Richmond Rd', 'Staten Island, NY 10304']},
#    'phone': '+17189877999',
#    'display_phone': '(718) 987-7999',
#    'distance': 2257.9015355717625},
#   {'id': 'ewJTFUjPEOVkYj4FUm-11g',
#    'alias': 'piece-a-cake-new-york-3',
#    'name': 'Piece A Cake',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/26P2aTHH7eOBo12HB034vA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/piece-a-cake-new-york-3?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 305,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.5734755325581,
#     'longitude': -74.1147970675453},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '177 New Dorp Ln',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['177 New Dorp Ln', 'New York, NY 10306']},
#    'phone': '+17189802253',
#    'display_phone': '(718) 980-2253',
#    'distance': 271.08917154365884},
#   {'id': 'uteLxmXMOtfUhfBL9sbrLw',
#    'alias': 'subway-staten-island-40',
#    'name': 'Subway',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IaxHQVq3lJWBDgHN55D98w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/subway-staten-island-40?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 3,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.5645129124965,
#     'longitude': -74.1280255469758},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '86 Guyon Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['86 Guyon Ave', 'Staten Island, NY 10306']},
#    'phone': '+17185244097',
#    'display_phone': '(718) 524-4097',
#    'distance': 1485.813345486533},
#   {'id': 'thQq8A9RooELqu9_74EZRQ',
#    'alias': 'five-guys-staten-island-3',
#    'name': 'Five Guys',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/c0_6QNr0fnMAhZtJ7OOEWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/five-guys-staten-island-3?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 21,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.56534, 'longitude': -74.11447},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '2754 Hylan Blvd',
#     'address2': None,
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2754 Hylan Blvd', 'Staten Island, NY 10306']},
#    'phone': '+19175882281',
#    'display_phone': '(917) 588-2281',
#    'distance': 869.6758159361835},
#   {'id': 'ySEJ0axD_lSfsAMOApAh4Q',
#    'alias': 'brioso-staten-island',
#    'name': 'Brioso',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Sf3WJr1oCM9AKApTonGojQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brioso-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 79,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.573052, 'longitude': -74.115113},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '174 New Dorp Ln',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['174 New Dorp Ln', 'Staten Island, NY 10306']},
#    'phone': '+17186671700',
#    'display_phone': '(718) 667-1700',
#    'distance': 251.77950670146038},
#   {'id': 'JdpT_5liovYNXRlQaHLHMg',
#    'alias': 'darios-pizzeria-staten-island',
#    'name': "Dario's Pizzeria",
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/darios-pizzeria-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 1,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.58129, 'longitude': -74.11149},
#    'transactions': [],
#    'location': {'address1': '2110 Richmond Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2110 Richmond Rd', 'Staten Island, NY 10306']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1119.0874410621886},
#   {'id': 'sXxpqjRajbspzLRdv_6QBw',
#    'alias': 'simple-asia-staten-island',
#    'name': 'Simple Asia',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/msMpN2X9dRGO96gwIGzM2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/simple-asia-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 120,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.5746530841284,
#     'longitude': -74.1058338806033},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2333 Hylan Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2333 Hylan Blvd', 'Staten Island, NY 10306']},
#    'phone': '+17189798868',
#    'display_phone': '(718) 979-8868',
#    'distance': 701.664367103952},
#   {'id': 'YDorQeInbcXaOq_fVY0-VA',
#    'alias': 'hylan-diner-staten-island',
#    'name': 'Hylan Diner',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y0ZuUdKx_KuGNWGeJjp6Tw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hylan-diner-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 96,
#    'categories': [{'alias': 'diners', 'title': 'Diners'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.56915, 'longitude': -74.11156},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2561 Hylan Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2561 Hylan Blvd', 'Staten Island, NY 10306']},
#    'phone': '+17186689200',
#    'display_phone': '(718) 668-9200',
#    'distance': 268.96510828939927},
#   {'id': 'RSQeWL6CWU7ji6tcqAiXEA',
#    'alias': 'better-gourmet-health-kitchen-staten-island-2',
#    'name': 'Better Gourmet Health Kitchen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/yNipBxXhFfjqzEa3nMcrGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/better-gourmet-health-kitchen-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 58,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.57425, 'longitude': -74.106426},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2333 Hylan Blvd',
#     'address2': None,
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2333 Hylan Blvd', 'Staten Island, NY 10306']},
#    'phone': '+17186680400',
#    'display_phone': '(718) 668-0400',
#    'distance': 656.1998509680686},
#   {'id': 'fsZIYlkhLbZjUpqQtjGeHQ',
#    'alias': 'canlons-restaurant-staten-island',
#    'name': "Canlon's Restaurant",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/plEHye96j5lWH_tBA2m9wQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/canlons-restaurant-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 76,
#    'categories': [{'alias': 'tradamerican',
#      'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.565179, 'longitude': -74.126835},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1825 N Railroad Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1825 N Railroad Ave', 'Staten Island, NY 10306']},
#    'phone': '+17186673013',
#    'display_phone': '(718) 667-3013',
#    'distance': 1356.5405525370807},
#   {'id': 'fxjygBjQqWSE71Ref2s0oA',
#    'alias': 'michaels-martinis-and-meatballs-staten-island',
#    'name': "Michael's Martinis & Meatballs",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DBfQZum2kXFVKSsjeK7aRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/michaels-martinis-and-meatballs-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 228,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.584706, 'longitude': -74.093654},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1816 Hylan Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10305',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1816 Hylan Blvd', 'Staten Island, NY 10305']},
#    'phone': '+13476958160',
#    'display_phone': '(347) 695-8160',
#    'distance': 2199.783835856638},
#   {'id': 'V4CgzKda_7bTqa3UTuRFCw',
#    'alias': 'avocado-sushi-staten-island-2',
#    'name': 'Avocado Sushi',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/p_p4aR6BeuDGTTfNd1LxqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/avocado-sushi-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 70,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.582986, 'longitude': -74.097047},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1919 Hylan Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10305',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1919 Hylan Blvd', 'Staten Island, NY 10305']},
#    'phone': '+17186681400',
#    'display_phone': '(718) 668-1400',
#    'distance': 1870.393773887724},
#   {'id': 'jNhMXvGQ2WonmfXWeDoxDw',
#    'alias': 'fresh-tortillas-and-taco-staten-island-2',
#    'name': 'Fresh Tortillas & Taco',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/J7mIEFuXBdUzwlMVHBvQhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fresh-tortillas-and-taco-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 73,
#    'categories': [{'alias': 'tex-mex', 'title': 'Tex-Mex'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.5717329, 'longitude': -74.112404},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '304 New Dorp Ln',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['304 New Dorp Ln', 'Staten Island, NY 10306']},
#    'phone': '+17189796666',
#    'display_phone': '(718) 979-6666',
#    'distance': 55.83745027671269},
#   {'id': 'aJkb_Ek9iZJUKgH5-cu7wQ',
#    'alias': 'nori-sushi-staten-island',
#    'name': 'Nori Sushi',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/uqfOZGj4a7D9BRF7b1IH5w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nori-sushi-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 87,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.5738067626953,
#     'longitude': -74.1175994873047},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '55 New Dorp Plz',
#     'address2': None,
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 New Dorp Plz', 'Staten Island, NY 10306']},
#    'phone': '+17186680288',
#    'display_phone': '(718) 668-0288',
#    'distance': 465.75064634089233},
#   {'id': 'lyKgV-M9XKm9osK6bT1a-Q',
#    'alias': 'cafe-con-pan-staten-island',
#    'name': 'Cafe Con Pan',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uFWd__n6agmJSrYEAWCEUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-con-pan-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 37,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.5737, 'longitude': -74.116305},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '32 New Dorp Plz S',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32 New Dorp Plz S', 'Staten Island, NY 10306']},
#    'phone': '+13478610364',
#    'display_phone': '(347) 861-0364',
#    'distance': 374.5182234200522},
#   {'id': 'x_ojll0Ik-UPyXnSkgFBPQ',
#    'alias': 'corner-house-bbq-staten-island',
#    'name': 'Corner House BBQ',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XJWAqZmOEJk9nXl2mX0mqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/corner-house-bbq-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 259,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.579608, 'longitude': -74.1095},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '102 Lincoln Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['102 Lincoln Ave', 'Staten Island, NY 10306']},
#    'phone': '+17189871227',
#    'display_phone': '(718) 987-1227',
#    'distance': 953.2535922070606},
#   {'id': '0xl3JnEgbA4P6KKfJYup6w',
#    'alias': 'violettes-cellar-staten-island',
#    'name': "Violette's Cellar",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Kgf4FwkjwhVuh41f2VYWBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/violettes-cellar-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 253,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'speakeasies', 'title': 'Speakeasies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.57547, 'longitude': -74.10499},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2271 Hylan Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2271 Hylan Blvd', 'Staten Island, NY 10306']},
#    'phone': '+17186505050',
#    'display_phone': '(718) 650-5050',
#    'distance': 790.6578579752085},
#   {'id': '_dhsOIr9dfCBuaAM6lX7vA',
#    'alias': 'new-china-buffet-staten-island',
#    'name': 'New China Buffet',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SczTGSaVs2YIXOe_tLJdCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-china-buffet-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 81,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.567711, 'longitude': -74.111769},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2626 Hylan Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2626 Hylan Blvd', 'Staten Island, NY 10306']},
#    'phone': '+17189873388',
#    'display_phone': '(718) 987-3388',
#    'distance': 429.26222086456187},
#   {'id': 'HsjdcO2rJ22XFyeIOVeQFg',
#    'alias': 'cafe-gourmand-staten-island',
#    'name': 'Cafe Gourmand',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qK-23u5BYXdbBL_scKa83A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-gourmand-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 23,
#    'categories': [{'alias': 'russian', 'title': 'Russian'},
#     {'alias': 'armenian', 'title': 'Armenian'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.57193, 'longitude': -74.095222},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '548 Lincoln Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['548 Lincoln Ave', 'Staten Island, NY 10306']},
#    'phone': '+17183517575',
#    'display_phone': '(718) 351-7575',
#    'distance': 1507.8070730916056},
#   {'id': 'U6kLMaDnq6tBD83U0YHshg',
#    'alias': 'fushimi-todt-hill-staten-island',
#    'name': 'Fushimi Todt Hill',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dZTZng2naMW1UABdV-7b3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fushimi-todt-hill-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 184,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.581292, 'longitude': -74.111488},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2110 Richmond Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2110 Richmond Rd', 'Staten Island, NY 10306']},
#    'phone': '+17189805300',
#    'display_phone': '(718) 980-5300',
#    'distance': 1119.0874410621886},
#   {'id': 'cZRaFlLacN5Evf7dO9pHig',
#    'alias': 'china-taste-staten-island',
#    'name': 'China Taste',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RHqpzVAm0d_a1P_FS-JaQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/china-taste-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 10,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.5848791, 'longitude': -74.093588},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '1812 Hylan Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10305',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1812 Hylan Blvd', 'Staten Island, NY 10305']},
#    'phone': '+17189875269',
#    'display_phone': '(718) 987-5269',
#    'distance': 2217.7288990206234},
#   {'id': 'lDVHKeiRdiQ2hL5nMzG49w',
#    'alias': 'jimmy-max-staten-island-3',
#    'name': 'Jimmy Max',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jimmy-max-staten-island-3?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 2,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 40.586094, 'longitude': -74.104576},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1820 Richmond Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1820 Richmond Rd', 'Staten Island, NY 10306']},
#    'phone': '+17189836715',
#    'display_phone': '(718) 983-6715',
#    'distance': 1776.1870180190972},
#   {'id': '2TOtrDhkQjaOJWwJJr0tUQ',
#    'alias': 'nakata-staten-island',
#    'name': 'Nakata',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YnjZDszdj3DkKJTCYTc3dg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nakata-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 132,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.58823, 'longitude': -74.103685},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1775 D Richmond Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10304',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1775 D Richmond Rd', 'Staten Island, NY 10304']},
#    'phone': '+17189801891',
#    'display_phone': '(718) 980-1891',
#    'distance': 2024.0883339608201}],
#  'total': 55,
#  'region': {'center': {'longitude': -74.11299705505371,
#    'latitude': 40.57145704856859}}}

# %%
response.json()
# Out:
# {'businesses': [{'id': 'LlT5XLc88hFDcWiCKskasg',
#    'alias': 'pizzeria-giove-staten-island',
#    'name': 'Pizzeria Giove',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/w-Ne6LJLVLnmJlJJBazRsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pizzeria-giove-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 307,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.57215, 'longitude': -74.1131599},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '278 New Dorp Ln',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['278 New Dorp Ln', 'Staten Island, NY 10306']},
#    'phone': '+13472860635',
#    'display_phone': '(347) 286-0635',
#    'distance': 75.34648018324394},
#   {'id': 'eendqrZ9Cp_JisaDtoBU4w',
#    'alias': 'bravo-pizza-staten-island',
#    'name': 'Bravo Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/98GIefvXOn22c6qrv3ebMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bravo-pizza-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 11,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.5701278126894,
#     'longitude': -74.108795389156},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '413  New Dorp Ln',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['413  New Dorp Ln', 'Staten Island, NY 10306']},
#    'phone': '+17183171010',
#    'display_phone': '(718) 317-1010',
#    'distance': 384.43767528529156},
#   {'id': '-jdadX3fGXA2TDapnufYFA',
#    'alias': 'dough-by-licastri-staten-island',
#    'name': 'DOUGH By Licastri',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eHIjhfgelm1nBhir7Rq_-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dough-by-licastri-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 131,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.59391, 'longitude': -74.09948},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1456 Richmond Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10304',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1456 Richmond Rd', 'Staten Island, NY 10304']},
#    'phone': '+17186681600',
#    'display_phone': '(718) 668-1600',
#    'distance': 2744.5071665458286},
#   {'id': '2NBbuLr9JWEzfbvML83Dkg',
#    'alias': 'giacomos-pizzeria-staten-island',
#    'name': 'Giacomos Pizzeria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tUNTsQo16oggOlR_OpHejQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/giacomos-pizzeria-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 34,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.57326, 'longitude': -74.11522},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '170 New Dorp Ln',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['170 New Dorp Ln', 'Staten Island, NY 10306']},
#    'phone': '+17186680490',
#    'display_phone': '(718) 668-0490',
#    'distance': 271.76136780900123},
#   {'id': 'Chaq0plYdKIILsAfAFvwBA',
#    'alias': 'nunzios-pizzeria-and-restaurant-staten-island',
#    'name': "Nunzio's Pizzeria & Restaurant",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/upT_UvNekVt8LQPckOVWQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nunzios-pizzeria-and-restaurant-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 109,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.57799, 'longitude': -74.10271},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '2155 Hylan Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2155 Hylan Blvd', 'Staten Island, NY 10306']},
#    'phone': '+17186679647',
#    'display_phone': '(718) 667-9647',
#    'distance': 1132.1659743860528},
#   {'id': 'U0HmnNv1wJL-dANj_Dq71A',
#    'alias': 'lees-tavern-staten-island',
#    'name': "Lee's Tavern",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XzJqQB18-UeZaeWrsHyyGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lees-tavern-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 498,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.588756, 'longitude': -74.095153},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '60 Hancock St',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10305',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['60 Hancock St', 'Staten Island, NY 10305']},
#    'phone': '+17186679749',
#    'display_phone': '(718) 667-9749',
#    'distance': 2443.1955234493444},
#   {'id': 'yWGdfTjzk0KDjrUpUan5vA',
#    'alias': 'prime-pizza-kitchen-staten-island',
#    'name': 'Prime Pizza Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_TimNJnhQIAwyYrQK59vEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/prime-pizza-kitchen-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 47,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.5853249350922,
#     'longitude': -74.0926520634632},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '1778 Hylan Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10305',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1778 Hylan Blvd', 'Staten Island, NY 10305']},
#    'phone': '+17183515000',
#    'display_phone': '(718) 351-5000',
#    'distance': 2308.715085845923},
#   {'id': '9JFO3le5_jl5_yaC4fKLbw',
#    'alias': 'restaurant-on-the-plaza-pizzeria-staten-island',
#    'name': 'Restaurant On the Plaza Pizzeria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QkT8bHcjs6sNdGP-GhAD0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/restaurant-on-the-plaza-pizzeria-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 20,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.57338, 'longitude': -74.11664},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '50 New Dorp Plz',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['50 New Dorp Plz', 'Staten Island, NY 10306']},
#    'phone': '+17186677170',
#    'display_phone': '(718) 667-7170',
#    'distance': 386.15973125965326},
#   {'id': '-m8hYUDP6howLkVkEzBGSg',
#    'alias': 'pronto-pizza-staten-island-3',
#    'name': 'Pronto Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_gkJFPtrnC6sxZ9mntUC0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pronto-pizza-staten-island-3?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 49,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.57147, 'longitude': -74.1111},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '337 New Dorp Ln',
#     'address2': None,
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['337 New Dorp Ln', 'Staten Island, NY 10306']},
#    'phone': '+17183512700',
#    'display_phone': '(718) 351-2700',
#    'distance': 157.99406266087638},
#   {'id': '461hss6jSwjN8FdiZgN6wA',
#    'alias': 'the-original-goodfellas-brick-oven-pizza-staten-island-2',
#    'name': "The Original Goodfella's Brick Oven Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6DQT6mdKn05HGmDapqlRgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-original-goodfellas-brick-oven-pizza-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 246,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.586785, 'longitude': -74.091438},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1718 Hylan Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10305',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1718 Hylan Blvd', 'Staten Island, NY 10305']},
#    'phone': '+17189872422',
#    'display_phone': '(718) 987-2422',
#    'distance': 2493.9961938672122},
#   {'id': 'iPLXtSD442PQXnlC5jAqbg',
#    'alias': 'cucina-fresca-staten-island-2',
#    'name': 'Cucina Fresca',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Q5W4Q6JvpSSe4CNInCywLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cucina-fresca-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 88,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.581292, 'longitude': -74.111488},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2110 Richmond Rd',
#     'address2': 'Ste 6',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2110 Richmond Rd',
#      'Ste 6',
#      'Staten Island, NY 10306']},
#    'phone': '+17186675152',
#    'display_phone': '(718) 667-5152',
#    'distance': 1119.0874410621886},
#   {'id': 'SNX8DPWkqhPDYnw2k0QUGA',
#    'alias': 'ny-family-pizza-staten-island',
#    'name': 'NY Family Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VGMMqzvV1j7SwFb9gsza_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ny-family-pizza-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 16,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.58329, 'longitude': -74.095077},
#    'transactions': [],
#    'location': {'address1': '1880 Hylan Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10305',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1880 Hylan Blvd', 'Staten Island, NY 10305']},
#    'phone': '+17189877000',
#    'display_phone': '(718) 987-7000',
#    'distance': 2005.4323725744332},
#   {'id': 'OBz9S_wgdXKxIX1CbU41Lw',
#    'alias': 'cuzzin-joes-pizza-staten-island',
#    'name': 'Cuzzin Joes Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2okReqJ2-fLzElfKVW7gww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cuzzin-joes-pizza-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 3,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.572232, 'longitude': -74.093347},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '572 Midland Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['572 Midland Ave', 'Staten Island, NY 10306']},
#    'phone': '+17183519333',
#    'display_phone': '(718) 351-9333',
#    'distance': 1660.9745970802119},
#   {'id': 'lnY_TfGOGeRs00tHIi0T1w',
#    'alias': 'via-napoli-staten-island-2',
#    'name': 'Via Napoli',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hRvF9v4cXbaxVVyvojYBjQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/via-napoli-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 68,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.56743, 'longitude': -74.11138},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '2626 Hylan Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2626 Hylan Blvd', 'Staten Island, NY 10306']},
#    'phone': '+17186678599',
#    'display_phone': '(718) 667-8599',
#    'distance': 462.2399838771992},
#   {'id': 'wvXF3ESpaU9ly_er_DEzxQ',
#    'alias': 'ambrosinos-pizzeria-staten-island',
#    'name': "Ambrosino's Pizzeria",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DtvBxYwRyuoFwr6376EqKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ambrosinos-pizzeria-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 35,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.564278, 'longitude': -74.133473},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '3161 Amboy Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3161 Amboy Rd', 'Staten Island, NY 10306']},
#    'phone': '+17189878800',
#    'display_phone': '(718) 987-8800',
#    'distance': 1904.8873603938653},
#   {'id': 'P2C2U2LRC-POjGClJMKr6A',
#    'alias': 'domenicos-pizza-staten-island-51',
#    'name': "Domenico's Pizza",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ARBdRD6drM4wdAFJkz3MQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/domenicos-pizza-staten-island-51?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 58,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.561036, 'longitude': -74.135384},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '3295 Amboy Rd',
#     'address2': 'Ste 3',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3295 Amboy Rd', 'Ste 3', 'Staten Island, NY 10306']},
#    'phone': '+17183512100',
#    'display_phone': '(718) 351-2100',
#    'distance': 2217.8109660697214},
#   {'id': 'GoODm3ptRYL964UeYbKPkQ',
#    'alias': 'justinos-pizzeria-staten-island',
#    'name': "Justino's Pizzeria",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Y_frBA2b-T7uga_3wAmrfg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/justinos-pizzeria-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 48,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.5649, 'longitude': -74.12772},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '89 Guyon Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['89 Guyon Ave', 'Staten Island, NY 10306']},
#    'phone': '+17186682020',
#    'display_phone': '(718) 668-2020',
#    'distance': 1439.7485565451568},
#   {'id': 'VAi8d2WDjjKN7saJ2rNRHg',
#    'alias': 'classic-pizza-staten-island-2',
#    'name': 'Classic Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zAkUlUzbEYob2_6PMpKjGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/classic-pizza-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 21,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.575512, 'longitude': -74.127824},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '3201 Richmond Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3201 Richmond Rd', 'Staten Island, NY 10306']},
#    'phone': '+17189872500',
#    'display_phone': '(718) 987-2500',
#    'distance': 1338.548091147004},
#   {'id': 'q4CBRjGixsHaK0Abm-byNw',
#    'alias': 'panino-rustico-staten-island-staten-island',
#    'name': 'Panino Rustico - Staten Island',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/V7jJEWJv1fbguORCb7GwuQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/panino-rustico-staten-island-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 91,
#    'categories': [{'alias': 'creperies', 'title': 'Creperies'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.58129, 'longitude': -74.11149},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2110 Richmond Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2110 Richmond Rd', 'Staten Island, NY 10306']},
#    'phone': '+17183510100',
#    'display_phone': '(718) 351-0100',
#    'distance': 1119.0874410621886},
#   {'id': 'lDz5EIOmtua_tl-UcY78wA',
#    'alias': 'sharkeys-square-pizza-staten-island',
#    'name': "Sharkey's Square Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LaqmQn2wE3W8oT74hNi7iA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sharkeys-square-pizza-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 48,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.5827865600586,
#     'longitude': -74.0960235595703},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '1910 Hylan Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10305',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1910 Hylan Blvd', 'Staten Island, NY 10305']},
#    'phone': '+17189794700',
#    'display_phone': '(718) 979-4700',
#    'distance': 1908.5896701189322},
#   {'id': 'pncElrotZZCTr_l1bWtB6w',
#    'alias': 'torino-cafe-staten-island-2',
#    'name': 'Torino Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/11ZcXncCmK4gJ8O4Y2mDyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/torino-cafe-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 16,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.58882, 'longitude': -74.1018},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1694 Richmond Rd',
#     'address2': None,
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10304',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1694 Richmond Rd', 'Staten Island, NY 10304']},
#    'phone': '+17183513100',
#    'display_phone': '(718) 351-3100',
#    'distance': 2147.9663213616604},
#   {'id': 'eMMF_kyHQIrX_An67wYcpA',
#    'alias': 'griffs-place-new-dorp-beach',
#    'name': "Griff's Place",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/I3ZxAUjOWHtRcE8p5PQ4SQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/griffs-place-new-dorp-beach?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 61,
#    'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.5656772, 'longitude': -74.100421},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '704 New Dorp Ln',
#     'address2': '',
#     'address3': '',
#     'city': 'New Dorp Beach',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['704 New Dorp Ln', 'New Dorp Beach, NY 10306']},
#    'phone': '+17186682645',
#    'display_phone': '(718) 668-2645',
#    'distance': 1232.371971624808},
#   {'id': 'KMLT72-bHysWDTqbzunhDw',
#    'alias': 'little-italy-gourmet-staten-island',
#    'name': 'Little Italy Gourmet',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/sBl_b4UGrno-QbUBhAwR4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-italy-gourmet-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 25,
#    'categories': [{'alias': 'intlgrocery', 'title': 'International Grocery'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.57489, 'longitude': -74.116065},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1375 N Railroad Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1375 N Railroad Ave', 'Staten Island, NY 10306']},
#    'phone': '+17189803663',
#    'display_phone': '(718) 980-3663',
#    'distance': 460.2778480603174},
#   {'id': 'lr0M6lCGZPzijNlHz3ZGsA',
#    'alias': 'kim-cooks-and-caters-staten-island',
#    'name': 'Kim Cooks & Caters',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/54vGCyMXlZdZ57eyEukkaA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kim-cooks-and-caters-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 16,
#    'categories': [{'alias': 'catering', 'title': 'Caterers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.579906, 'longitude': -74.109256},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '97 Lincoln Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['97 Lincoln Ave', 'Staten Island, NY 10306']},
#    'phone': '+12124252623',
#    'display_phone': '(212) 425-2623',
#    'distance': 992.3150623690841},
#   {'id': 'kE0nfIY9l_guZTo8AlfHeg',
#    'alias': 'fresh-twist-juicebar-and-cafe-staten-island',
#    'name': 'Fresh Twist juicebar & cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/eXWAVjrq57L89p2qU6kmow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fresh-twist-juicebar-and-cafe-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 58,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'empanadas', 'title': 'Empanadas'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.5753893, 'longitude': -74.1192837},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '10 New Dorp Ln',
#     'address2': None,
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['10 New Dorp Ln', 'Staten Island, NY 10306']},
#    'phone': '+19178301644',
#    'display_phone': '(917) 830-1644',
#    'distance': 719.9921010341428},
#   {'id': 'iXfgnXG-LKT5R0ZlUbSHlA',
#    'alias': 'papa-johns-pizza-staten-island-2',
#    'name': "Papa John's Pizza",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cRJxEZWBnTemsiXlzPfqBw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/papa-johns-pizza-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 15,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 1.5,
#    'coordinates': {'latitude': 40.577494, 'longitude': -74.103382},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '2175 Hyland Blvd.',
#     'address2': None,
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2175 Hyland Blvd.', 'Staten Island, NY 10306']},
#    'phone': '+17186673474',
#    'display_phone': '(718) 667-3474',
#    'distance': 1053.607211325036},
#   {'id': '1Xfz59j6iyGH6Z-GtSJblA',
#    'alias': 'how-greek-it-is-staten-island',
#    'name': 'How Greek It Is',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SkP80p8TRthZr2F3zBW6Fg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/how-greek-it-is-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 126,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.5760758, 'longitude': -74.1033838},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2224 Hylan Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2224 Hylan Blvd', 'Staten Island, NY 10306']},
#    'phone': '+17182733200',
#    'display_phone': '(718) 273-3200',
#    'distance': 960.7326315037509},
#   {'id': 'SNTBdiEi55Zvt3qa4AAEJg',
#    'alias': 'sakana-sushi-and-hibachi-steakhouse-staten-island',
#    'name': 'Sakana Sushi & Hibachi Steakhouse',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2A3iBAhvVfunyW8L8KmZGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sakana-sushi-and-hibachi-steakhouse-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 13,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.589737938998,
#     'longitude': -74.1013584556552},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1657 Richmond Rd',
#     'address2': None,
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10304',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1657 Richmond Rd', 'Staten Island, NY 10304']},
#    'phone': '+17189877999',
#    'display_phone': '(718) 987-7999',
#    'distance': 2257.9015355717625},
#   {'id': 'ewJTFUjPEOVkYj4FUm-11g',
#    'alias': 'piece-a-cake-new-york-3',
#    'name': 'Piece A Cake',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/26P2aTHH7eOBo12HB034vA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/piece-a-cake-new-york-3?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 305,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.5734755325581,
#     'longitude': -74.1147970675453},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '177 New Dorp Ln',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['177 New Dorp Ln', 'New York, NY 10306']},
#    'phone': '+17189802253',
#    'display_phone': '(718) 980-2253',
#    'distance': 271.08917154365884},
#   {'id': 'uteLxmXMOtfUhfBL9sbrLw',
#    'alias': 'subway-staten-island-40',
#    'name': 'Subway',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IaxHQVq3lJWBDgHN55D98w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/subway-staten-island-40?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 3,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.5645129124965,
#     'longitude': -74.1280255469758},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '86 Guyon Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['86 Guyon Ave', 'Staten Island, NY 10306']},
#    'phone': '+17185244097',
#    'display_phone': '(718) 524-4097',
#    'distance': 1485.813345486533},
#   {'id': 'thQq8A9RooELqu9_74EZRQ',
#    'alias': 'five-guys-staten-island-3',
#    'name': 'Five Guys',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/c0_6QNr0fnMAhZtJ7OOEWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/five-guys-staten-island-3?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 21,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.56534, 'longitude': -74.11447},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '2754 Hylan Blvd',
#     'address2': None,
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2754 Hylan Blvd', 'Staten Island, NY 10306']},
#    'phone': '+19175882281',
#    'display_phone': '(917) 588-2281',
#    'distance': 869.6758159361835},
#   {'id': 'ySEJ0axD_lSfsAMOApAh4Q',
#    'alias': 'brioso-staten-island',
#    'name': 'Brioso',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Sf3WJr1oCM9AKApTonGojQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brioso-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 79,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.573052, 'longitude': -74.115113},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '174 New Dorp Ln',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['174 New Dorp Ln', 'Staten Island, NY 10306']},
#    'phone': '+17186671700',
#    'display_phone': '(718) 667-1700',
#    'distance': 251.77950670146038},
#   {'id': 'JdpT_5liovYNXRlQaHLHMg',
#    'alias': 'darios-pizzeria-staten-island',
#    'name': "Dario's Pizzeria",
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/darios-pizzeria-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 1,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.58129, 'longitude': -74.11149},
#    'transactions': [],
#    'location': {'address1': '2110 Richmond Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2110 Richmond Rd', 'Staten Island, NY 10306']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1119.0874410621886},
#   {'id': 'sXxpqjRajbspzLRdv_6QBw',
#    'alias': 'simple-asia-staten-island',
#    'name': 'Simple Asia',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/msMpN2X9dRGO96gwIGzM2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/simple-asia-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 120,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.5746530841284,
#     'longitude': -74.1058338806033},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2333 Hylan Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2333 Hylan Blvd', 'Staten Island, NY 10306']},
#    'phone': '+17189798868',
#    'display_phone': '(718) 979-8868',
#    'distance': 701.664367103952},
#   {'id': 'YDorQeInbcXaOq_fVY0-VA',
#    'alias': 'hylan-diner-staten-island',
#    'name': 'Hylan Diner',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y0ZuUdKx_KuGNWGeJjp6Tw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hylan-diner-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 96,
#    'categories': [{'alias': 'diners', 'title': 'Diners'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.56915, 'longitude': -74.11156},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2561 Hylan Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2561 Hylan Blvd', 'Staten Island, NY 10306']},
#    'phone': '+17186689200',
#    'display_phone': '(718) 668-9200',
#    'distance': 268.96510828939927},
#   {'id': 'RSQeWL6CWU7ji6tcqAiXEA',
#    'alias': 'better-gourmet-health-kitchen-staten-island-2',
#    'name': 'Better Gourmet Health Kitchen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/yNipBxXhFfjqzEa3nMcrGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/better-gourmet-health-kitchen-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 58,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.57425, 'longitude': -74.106426},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2333 Hylan Blvd',
#     'address2': None,
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2333 Hylan Blvd', 'Staten Island, NY 10306']},
#    'phone': '+17186680400',
#    'display_phone': '(718) 668-0400',
#    'distance': 656.1998509680686},
#   {'id': 'fsZIYlkhLbZjUpqQtjGeHQ',
#    'alias': 'canlons-restaurant-staten-island',
#    'name': "Canlon's Restaurant",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/plEHye96j5lWH_tBA2m9wQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/canlons-restaurant-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 76,
#    'categories': [{'alias': 'tradamerican',
#      'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.565179, 'longitude': -74.126835},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1825 N Railroad Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1825 N Railroad Ave', 'Staten Island, NY 10306']},
#    'phone': '+17186673013',
#    'display_phone': '(718) 667-3013',
#    'distance': 1356.5405525370807},
#   {'id': 'fxjygBjQqWSE71Ref2s0oA',
#    'alias': 'michaels-martinis-and-meatballs-staten-island',
#    'name': "Michael's Martinis & Meatballs",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DBfQZum2kXFVKSsjeK7aRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/michaels-martinis-and-meatballs-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 228,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.584706, 'longitude': -74.093654},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1816 Hylan Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10305',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1816 Hylan Blvd', 'Staten Island, NY 10305']},
#    'phone': '+13476958160',
#    'display_phone': '(347) 695-8160',
#    'distance': 2199.783835856638},
#   {'id': 'V4CgzKda_7bTqa3UTuRFCw',
#    'alias': 'avocado-sushi-staten-island-2',
#    'name': 'Avocado Sushi',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/p_p4aR6BeuDGTTfNd1LxqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/avocado-sushi-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 70,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.582986, 'longitude': -74.097047},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1919 Hylan Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10305',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1919 Hylan Blvd', 'Staten Island, NY 10305']},
#    'phone': '+17186681400',
#    'display_phone': '(718) 668-1400',
#    'distance': 1870.393773887724},
#   {'id': 'jNhMXvGQ2WonmfXWeDoxDw',
#    'alias': 'fresh-tortillas-and-taco-staten-island-2',
#    'name': 'Fresh Tortillas & Taco',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/J7mIEFuXBdUzwlMVHBvQhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fresh-tortillas-and-taco-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 73,
#    'categories': [{'alias': 'tex-mex', 'title': 'Tex-Mex'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.5717329, 'longitude': -74.112404},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '304 New Dorp Ln',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['304 New Dorp Ln', 'Staten Island, NY 10306']},
#    'phone': '+17189796666',
#    'display_phone': '(718) 979-6666',
#    'distance': 55.83745027671269},
#   {'id': 'aJkb_Ek9iZJUKgH5-cu7wQ',
#    'alias': 'nori-sushi-staten-island',
#    'name': 'Nori Sushi',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/uqfOZGj4a7D9BRF7b1IH5w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nori-sushi-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 87,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.5738067626953,
#     'longitude': -74.1175994873047},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '55 New Dorp Plz',
#     'address2': None,
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 New Dorp Plz', 'Staten Island, NY 10306']},
#    'phone': '+17186680288',
#    'display_phone': '(718) 668-0288',
#    'distance': 465.75064634089233},
#   {'id': 'lyKgV-M9XKm9osK6bT1a-Q',
#    'alias': 'cafe-con-pan-staten-island',
#    'name': 'Cafe Con Pan',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uFWd__n6agmJSrYEAWCEUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-con-pan-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 37,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.5737, 'longitude': -74.116305},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '32 New Dorp Plz S',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32 New Dorp Plz S', 'Staten Island, NY 10306']},
#    'phone': '+13478610364',
#    'display_phone': '(347) 861-0364',
#    'distance': 374.5182234200522},
#   {'id': 'x_ojll0Ik-UPyXnSkgFBPQ',
#    'alias': 'corner-house-bbq-staten-island',
#    'name': 'Corner House BBQ',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XJWAqZmOEJk9nXl2mX0mqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/corner-house-bbq-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 259,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.579608, 'longitude': -74.1095},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '102 Lincoln Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['102 Lincoln Ave', 'Staten Island, NY 10306']},
#    'phone': '+17189871227',
#    'display_phone': '(718) 987-1227',
#    'distance': 953.2535922070606},
#   {'id': '0xl3JnEgbA4P6KKfJYup6w',
#    'alias': 'violettes-cellar-staten-island',
#    'name': "Violette's Cellar",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Kgf4FwkjwhVuh41f2VYWBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/violettes-cellar-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 253,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'speakeasies', 'title': 'Speakeasies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.57547, 'longitude': -74.10499},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2271 Hylan Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2271 Hylan Blvd', 'Staten Island, NY 10306']},
#    'phone': '+17186505050',
#    'display_phone': '(718) 650-5050',
#    'distance': 790.6578579752085},
#   {'id': '_dhsOIr9dfCBuaAM6lX7vA',
#    'alias': 'new-china-buffet-staten-island',
#    'name': 'New China Buffet',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SczTGSaVs2YIXOe_tLJdCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-china-buffet-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 81,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.567711, 'longitude': -74.111769},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2626 Hylan Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2626 Hylan Blvd', 'Staten Island, NY 10306']},
#    'phone': '+17189873388',
#    'display_phone': '(718) 987-3388',
#    'distance': 429.26222086456187},
#   {'id': 'HsjdcO2rJ22XFyeIOVeQFg',
#    'alias': 'cafe-gourmand-staten-island',
#    'name': 'Cafe Gourmand',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qK-23u5BYXdbBL_scKa83A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-gourmand-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 23,
#    'categories': [{'alias': 'russian', 'title': 'Russian'},
#     {'alias': 'armenian', 'title': 'Armenian'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.57193, 'longitude': -74.095222},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '548 Lincoln Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['548 Lincoln Ave', 'Staten Island, NY 10306']},
#    'phone': '+17183517575',
#    'display_phone': '(718) 351-7575',
#    'distance': 1507.8070730916056},
#   {'id': 'U6kLMaDnq6tBD83U0YHshg',
#    'alias': 'fushimi-todt-hill-staten-island',
#    'name': 'Fushimi Todt Hill',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dZTZng2naMW1UABdV-7b3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fushimi-todt-hill-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 184,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.581292, 'longitude': -74.111488},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2110 Richmond Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2110 Richmond Rd', 'Staten Island, NY 10306']},
#    'phone': '+17189805300',
#    'display_phone': '(718) 980-5300',
#    'distance': 1119.0874410621886},
#   {'id': 'cZRaFlLacN5Evf7dO9pHig',
#    'alias': 'china-taste-staten-island',
#    'name': 'China Taste',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RHqpzVAm0d_a1P_FS-JaQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/china-taste-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 10,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.5848791, 'longitude': -74.093588},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '1812 Hylan Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10305',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1812 Hylan Blvd', 'Staten Island, NY 10305']},
#    'phone': '+17189875269',
#    'display_phone': '(718) 987-5269',
#    'distance': 2217.7288990206234},
#   {'id': 'lDVHKeiRdiQ2hL5nMzG49w',
#    'alias': 'jimmy-max-staten-island-3',
#    'name': 'Jimmy Max',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jimmy-max-staten-island-3?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 2,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 40.586094, 'longitude': -74.104576},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1820 Richmond Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1820 Richmond Rd', 'Staten Island, NY 10306']},
#    'phone': '+17189836715',
#    'display_phone': '(718) 983-6715',
#    'distance': 1776.1870180190972},
#   {'id': '2TOtrDhkQjaOJWwJJr0tUQ',
#    'alias': 'nakata-staten-island',
#    'name': 'Nakata',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YnjZDszdj3DkKJTCYTc3dg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nakata-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 132,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.58823, 'longitude': -74.103685},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1775 D Richmond Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10304',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1775 D Richmond Rd', 'Staten Island, NY 10304']},
#    'phone': '+17189801891',
#    'display_phone': '(718) 980-1891',
#    'distance': 2024.0883339608201}],
#  'total': 55,
#  'region': {'center': {'longitude': -74.11299705505371,
#    'latitude': 40.57145704856859}}}

# %% [markdown]
# Using one of the methods above load the response data and assign it to a variable `data`.

# %%
data = json.loads(response.text)

# %%
data
# Out:
# {'businesses': [{'id': 'LlT5XLc88hFDcWiCKskasg',
#    'alias': 'pizzeria-giove-staten-island',
#    'name': 'Pizzeria Giove',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/w-Ne6LJLVLnmJlJJBazRsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pizzeria-giove-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 307,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.57215, 'longitude': -74.1131599},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '278 New Dorp Ln',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['278 New Dorp Ln', 'Staten Island, NY 10306']},
#    'phone': '+13472860635',
#    'display_phone': '(347) 286-0635',
#    'distance': 75.34648018324394},
#   {'id': 'eendqrZ9Cp_JisaDtoBU4w',
#    'alias': 'bravo-pizza-staten-island',
#    'name': 'Bravo Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/98GIefvXOn22c6qrv3ebMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bravo-pizza-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 11,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.5701278126894,
#     'longitude': -74.108795389156},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '413  New Dorp Ln',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['413  New Dorp Ln', 'Staten Island, NY 10306']},
#    'phone': '+17183171010',
#    'display_phone': '(718) 317-1010',
#    'distance': 384.43767528529156},
#   {'id': '-jdadX3fGXA2TDapnufYFA',
#    'alias': 'dough-by-licastri-staten-island',
#    'name': 'DOUGH By Licastri',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eHIjhfgelm1nBhir7Rq_-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dough-by-licastri-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 131,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.59391, 'longitude': -74.09948},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1456 Richmond Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10304',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1456 Richmond Rd', 'Staten Island, NY 10304']},
#    'phone': '+17186681600',
#    'display_phone': '(718) 668-1600',
#    'distance': 2744.5071665458286},
#   {'id': '2NBbuLr9JWEzfbvML83Dkg',
#    'alias': 'giacomos-pizzeria-staten-island',
#    'name': 'Giacomos Pizzeria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tUNTsQo16oggOlR_OpHejQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/giacomos-pizzeria-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 34,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.57326, 'longitude': -74.11522},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '170 New Dorp Ln',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['170 New Dorp Ln', 'Staten Island, NY 10306']},
#    'phone': '+17186680490',
#    'display_phone': '(718) 668-0490',
#    'distance': 271.76136780900123},
#   {'id': 'Chaq0plYdKIILsAfAFvwBA',
#    'alias': 'nunzios-pizzeria-and-restaurant-staten-island',
#    'name': "Nunzio's Pizzeria & Restaurant",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/upT_UvNekVt8LQPckOVWQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nunzios-pizzeria-and-restaurant-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 109,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.57799, 'longitude': -74.10271},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '2155 Hylan Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2155 Hylan Blvd', 'Staten Island, NY 10306']},
#    'phone': '+17186679647',
#    'display_phone': '(718) 667-9647',
#    'distance': 1132.1659743860528},
#   {'id': 'U0HmnNv1wJL-dANj_Dq71A',
#    'alias': 'lees-tavern-staten-island',
#    'name': "Lee's Tavern",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XzJqQB18-UeZaeWrsHyyGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lees-tavern-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 498,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.588756, 'longitude': -74.095153},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '60 Hancock St',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10305',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['60 Hancock St', 'Staten Island, NY 10305']},
#    'phone': '+17186679749',
#    'display_phone': '(718) 667-9749',
#    'distance': 2443.1955234493444},
#   {'id': 'yWGdfTjzk0KDjrUpUan5vA',
#    'alias': 'prime-pizza-kitchen-staten-island',
#    'name': 'Prime Pizza Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_TimNJnhQIAwyYrQK59vEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/prime-pizza-kitchen-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 47,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.5853249350922,
#     'longitude': -74.0926520634632},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '1778 Hylan Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10305',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1778 Hylan Blvd', 'Staten Island, NY 10305']},
#    'phone': '+17183515000',
#    'display_phone': '(718) 351-5000',
#    'distance': 2308.715085845923},
#   {'id': '9JFO3le5_jl5_yaC4fKLbw',
#    'alias': 'restaurant-on-the-plaza-pizzeria-staten-island',
#    'name': 'Restaurant On the Plaza Pizzeria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QkT8bHcjs6sNdGP-GhAD0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/restaurant-on-the-plaza-pizzeria-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 20,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.57338, 'longitude': -74.11664},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '50 New Dorp Plz',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['50 New Dorp Plz', 'Staten Island, NY 10306']},
#    'phone': '+17186677170',
#    'display_phone': '(718) 667-7170',
#    'distance': 386.15973125965326},
#   {'id': '-m8hYUDP6howLkVkEzBGSg',
#    'alias': 'pronto-pizza-staten-island-3',
#    'name': 'Pronto Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_gkJFPtrnC6sxZ9mntUC0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pronto-pizza-staten-island-3?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 49,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.57147, 'longitude': -74.1111},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '337 New Dorp Ln',
#     'address2': None,
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['337 New Dorp Ln', 'Staten Island, NY 10306']},
#    'phone': '+17183512700',
#    'display_phone': '(718) 351-2700',
#    'distance': 157.99406266087638},
#   {'id': '461hss6jSwjN8FdiZgN6wA',
#    'alias': 'the-original-goodfellas-brick-oven-pizza-staten-island-2',
#    'name': "The Original Goodfella's Brick Oven Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6DQT6mdKn05HGmDapqlRgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-original-goodfellas-brick-oven-pizza-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 246,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.586785, 'longitude': -74.091438},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1718 Hylan Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10305',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1718 Hylan Blvd', 'Staten Island, NY 10305']},
#    'phone': '+17189872422',
#    'display_phone': '(718) 987-2422',
#    'distance': 2493.9961938672122},
#   {'id': 'iPLXtSD442PQXnlC5jAqbg',
#    'alias': 'cucina-fresca-staten-island-2',
#    'name': 'Cucina Fresca',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Q5W4Q6JvpSSe4CNInCywLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cucina-fresca-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 88,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.581292, 'longitude': -74.111488},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2110 Richmond Rd',
#     'address2': 'Ste 6',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2110 Richmond Rd',
#      'Ste 6',
#      'Staten Island, NY 10306']},
#    'phone': '+17186675152',
#    'display_phone': '(718) 667-5152',
#    'distance': 1119.0874410621886},
#   {'id': 'SNX8DPWkqhPDYnw2k0QUGA',
#    'alias': 'ny-family-pizza-staten-island',
#    'name': 'NY Family Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VGMMqzvV1j7SwFb9gsza_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ny-family-pizza-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 16,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.58329, 'longitude': -74.095077},
#    'transactions': [],
#    'location': {'address1': '1880 Hylan Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10305',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1880 Hylan Blvd', 'Staten Island, NY 10305']},
#    'phone': '+17189877000',
#    'display_phone': '(718) 987-7000',
#    'distance': 2005.4323725744332},
#   {'id': 'OBz9S_wgdXKxIX1CbU41Lw',
#    'alias': 'cuzzin-joes-pizza-staten-island',
#    'name': 'Cuzzin Joes Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2okReqJ2-fLzElfKVW7gww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cuzzin-joes-pizza-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 3,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.572232, 'longitude': -74.093347},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '572 Midland Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['572 Midland Ave', 'Staten Island, NY 10306']},
#    'phone': '+17183519333',
#    'display_phone': '(718) 351-9333',
#    'distance': 1660.9745970802119},
#   {'id': 'lnY_TfGOGeRs00tHIi0T1w',
#    'alias': 'via-napoli-staten-island-2',
#    'name': 'Via Napoli',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hRvF9v4cXbaxVVyvojYBjQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/via-napoli-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 68,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.56743, 'longitude': -74.11138},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '2626 Hylan Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2626 Hylan Blvd', 'Staten Island, NY 10306']},
#    'phone': '+17186678599',
#    'display_phone': '(718) 667-8599',
#    'distance': 462.2399838771992},
#   {'id': 'wvXF3ESpaU9ly_er_DEzxQ',
#    'alias': 'ambrosinos-pizzeria-staten-island',
#    'name': "Ambrosino's Pizzeria",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DtvBxYwRyuoFwr6376EqKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ambrosinos-pizzeria-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 35,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.564278, 'longitude': -74.133473},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '3161 Amboy Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3161 Amboy Rd', 'Staten Island, NY 10306']},
#    'phone': '+17189878800',
#    'display_phone': '(718) 987-8800',
#    'distance': 1904.8873603938653},
#   {'id': 'P2C2U2LRC-POjGClJMKr6A',
#    'alias': 'domenicos-pizza-staten-island-51',
#    'name': "Domenico's Pizza",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ARBdRD6drM4wdAFJkz3MQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/domenicos-pizza-staten-island-51?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 58,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.561036, 'longitude': -74.135384},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '3295 Amboy Rd',
#     'address2': 'Ste 3',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3295 Amboy Rd', 'Ste 3', 'Staten Island, NY 10306']},
#    'phone': '+17183512100',
#    'display_phone': '(718) 351-2100',
#    'distance': 2217.8109660697214},
#   {'id': 'GoODm3ptRYL964UeYbKPkQ',
#    'alias': 'justinos-pizzeria-staten-island',
#    'name': "Justino's Pizzeria",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Y_frBA2b-T7uga_3wAmrfg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/justinos-pizzeria-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 48,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.5649, 'longitude': -74.12772},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '89 Guyon Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['89 Guyon Ave', 'Staten Island, NY 10306']},
#    'phone': '+17186682020',
#    'display_phone': '(718) 668-2020',
#    'distance': 1439.7485565451568},
#   {'id': 'VAi8d2WDjjKN7saJ2rNRHg',
#    'alias': 'classic-pizza-staten-island-2',
#    'name': 'Classic Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zAkUlUzbEYob2_6PMpKjGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/classic-pizza-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 21,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.575512, 'longitude': -74.127824},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '3201 Richmond Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3201 Richmond Rd', 'Staten Island, NY 10306']},
#    'phone': '+17189872500',
#    'display_phone': '(718) 987-2500',
#    'distance': 1338.548091147004},
#   {'id': 'q4CBRjGixsHaK0Abm-byNw',
#    'alias': 'panino-rustico-staten-island-staten-island',
#    'name': 'Panino Rustico - Staten Island',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/V7jJEWJv1fbguORCb7GwuQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/panino-rustico-staten-island-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 91,
#    'categories': [{'alias': 'creperies', 'title': 'Creperies'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.58129, 'longitude': -74.11149},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2110 Richmond Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2110 Richmond Rd', 'Staten Island, NY 10306']},
#    'phone': '+17183510100',
#    'display_phone': '(718) 351-0100',
#    'distance': 1119.0874410621886},
#   {'id': 'lDz5EIOmtua_tl-UcY78wA',
#    'alias': 'sharkeys-square-pizza-staten-island',
#    'name': "Sharkey's Square Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LaqmQn2wE3W8oT74hNi7iA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sharkeys-square-pizza-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 48,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.5827865600586,
#     'longitude': -74.0960235595703},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '1910 Hylan Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10305',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1910 Hylan Blvd', 'Staten Island, NY 10305']},
#    'phone': '+17189794700',
#    'display_phone': '(718) 979-4700',
#    'distance': 1908.5896701189322},
#   {'id': 'pncElrotZZCTr_l1bWtB6w',
#    'alias': 'torino-cafe-staten-island-2',
#    'name': 'Torino Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/11ZcXncCmK4gJ8O4Y2mDyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/torino-cafe-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 16,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.58882, 'longitude': -74.1018},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1694 Richmond Rd',
#     'address2': None,
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10304',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1694 Richmond Rd', 'Staten Island, NY 10304']},
#    'phone': '+17183513100',
#    'display_phone': '(718) 351-3100',
#    'distance': 2147.9663213616604},
#   {'id': 'eMMF_kyHQIrX_An67wYcpA',
#    'alias': 'griffs-place-new-dorp-beach',
#    'name': "Griff's Place",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/I3ZxAUjOWHtRcE8p5PQ4SQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/griffs-place-new-dorp-beach?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 61,
#    'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.5656772, 'longitude': -74.100421},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '704 New Dorp Ln',
#     'address2': '',
#     'address3': '',
#     'city': 'New Dorp Beach',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['704 New Dorp Ln', 'New Dorp Beach, NY 10306']},
#    'phone': '+17186682645',
#    'display_phone': '(718) 668-2645',
#    'distance': 1232.371971624808},
#   {'id': 'KMLT72-bHysWDTqbzunhDw',
#    'alias': 'little-italy-gourmet-staten-island',
#    'name': 'Little Italy Gourmet',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/sBl_b4UGrno-QbUBhAwR4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-italy-gourmet-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 25,
#    'categories': [{'alias': 'intlgrocery', 'title': 'International Grocery'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.57489, 'longitude': -74.116065},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1375 N Railroad Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1375 N Railroad Ave', 'Staten Island, NY 10306']},
#    'phone': '+17189803663',
#    'display_phone': '(718) 980-3663',
#    'distance': 460.2778480603174},
#   {'id': 'lr0M6lCGZPzijNlHz3ZGsA',
#    'alias': 'kim-cooks-and-caters-staten-island',
#    'name': 'Kim Cooks & Caters',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/54vGCyMXlZdZ57eyEukkaA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kim-cooks-and-caters-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 16,
#    'categories': [{'alias': 'catering', 'title': 'Caterers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.579906, 'longitude': -74.109256},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '97 Lincoln Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['97 Lincoln Ave', 'Staten Island, NY 10306']},
#    'phone': '+12124252623',
#    'display_phone': '(212) 425-2623',
#    'distance': 992.3150623690841},
#   {'id': 'kE0nfIY9l_guZTo8AlfHeg',
#    'alias': 'fresh-twist-juicebar-and-cafe-staten-island',
#    'name': 'Fresh Twist juicebar & cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/eXWAVjrq57L89p2qU6kmow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fresh-twist-juicebar-and-cafe-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 58,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'empanadas', 'title': 'Empanadas'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.5753893, 'longitude': -74.1192837},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '10 New Dorp Ln',
#     'address2': None,
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['10 New Dorp Ln', 'Staten Island, NY 10306']},
#    'phone': '+19178301644',
#    'display_phone': '(917) 830-1644',
#    'distance': 719.9921010341428},
#   {'id': 'iXfgnXG-LKT5R0ZlUbSHlA',
#    'alias': 'papa-johns-pizza-staten-island-2',
#    'name': "Papa John's Pizza",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cRJxEZWBnTemsiXlzPfqBw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/papa-johns-pizza-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 15,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 1.5,
#    'coordinates': {'latitude': 40.577494, 'longitude': -74.103382},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '2175 Hyland Blvd.',
#     'address2': None,
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2175 Hyland Blvd.', 'Staten Island, NY 10306']},
#    'phone': '+17186673474',
#    'display_phone': '(718) 667-3474',
#    'distance': 1053.607211325036},
#   {'id': '1Xfz59j6iyGH6Z-GtSJblA',
#    'alias': 'how-greek-it-is-staten-island',
#    'name': 'How Greek It Is',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SkP80p8TRthZr2F3zBW6Fg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/how-greek-it-is-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 126,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.5760758, 'longitude': -74.1033838},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2224 Hylan Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2224 Hylan Blvd', 'Staten Island, NY 10306']},
#    'phone': '+17182733200',
#    'display_phone': '(718) 273-3200',
#    'distance': 960.7326315037509},
#   {'id': 'SNTBdiEi55Zvt3qa4AAEJg',
#    'alias': 'sakana-sushi-and-hibachi-steakhouse-staten-island',
#    'name': 'Sakana Sushi & Hibachi Steakhouse',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2A3iBAhvVfunyW8L8KmZGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sakana-sushi-and-hibachi-steakhouse-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 13,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.589737938998,
#     'longitude': -74.1013584556552},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1657 Richmond Rd',
#     'address2': None,
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10304',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1657 Richmond Rd', 'Staten Island, NY 10304']},
#    'phone': '+17189877999',
#    'display_phone': '(718) 987-7999',
#    'distance': 2257.9015355717625},
#   {'id': 'ewJTFUjPEOVkYj4FUm-11g',
#    'alias': 'piece-a-cake-new-york-3',
#    'name': 'Piece A Cake',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/26P2aTHH7eOBo12HB034vA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/piece-a-cake-new-york-3?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 305,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.5734755325581,
#     'longitude': -74.1147970675453},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '177 New Dorp Ln',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['177 New Dorp Ln', 'New York, NY 10306']},
#    'phone': '+17189802253',
#    'display_phone': '(718) 980-2253',
#    'distance': 271.08917154365884},
#   {'id': 'uteLxmXMOtfUhfBL9sbrLw',
#    'alias': 'subway-staten-island-40',
#    'name': 'Subway',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IaxHQVq3lJWBDgHN55D98w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/subway-staten-island-40?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 3,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.5645129124965,
#     'longitude': -74.1280255469758},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '86 Guyon Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['86 Guyon Ave', 'Staten Island, NY 10306']},
#    'phone': '+17185244097',
#    'display_phone': '(718) 524-4097',
#    'distance': 1485.813345486533},
#   {'id': 'thQq8A9RooELqu9_74EZRQ',
#    'alias': 'five-guys-staten-island-3',
#    'name': 'Five Guys',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/c0_6QNr0fnMAhZtJ7OOEWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/five-guys-staten-island-3?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 21,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.56534, 'longitude': -74.11447},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '2754 Hylan Blvd',
#     'address2': None,
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2754 Hylan Blvd', 'Staten Island, NY 10306']},
#    'phone': '+19175882281',
#    'display_phone': '(917) 588-2281',
#    'distance': 869.6758159361835},
#   {'id': 'ySEJ0axD_lSfsAMOApAh4Q',
#    'alias': 'brioso-staten-island',
#    'name': 'Brioso',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Sf3WJr1oCM9AKApTonGojQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brioso-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 79,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.573052, 'longitude': -74.115113},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '174 New Dorp Ln',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['174 New Dorp Ln', 'Staten Island, NY 10306']},
#    'phone': '+17186671700',
#    'display_phone': '(718) 667-1700',
#    'distance': 251.77950670146038},
#   {'id': 'JdpT_5liovYNXRlQaHLHMg',
#    'alias': 'darios-pizzeria-staten-island',
#    'name': "Dario's Pizzeria",
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/darios-pizzeria-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 1,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.58129, 'longitude': -74.11149},
#    'transactions': [],
#    'location': {'address1': '2110 Richmond Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2110 Richmond Rd', 'Staten Island, NY 10306']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1119.0874410621886},
#   {'id': 'sXxpqjRajbspzLRdv_6QBw',
#    'alias': 'simple-asia-staten-island',
#    'name': 'Simple Asia',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/msMpN2X9dRGO96gwIGzM2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/simple-asia-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 120,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.5746530841284,
#     'longitude': -74.1058338806033},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2333 Hylan Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2333 Hylan Blvd', 'Staten Island, NY 10306']},
#    'phone': '+17189798868',
#    'display_phone': '(718) 979-8868',
#    'distance': 701.664367103952},
#   {'id': 'YDorQeInbcXaOq_fVY0-VA',
#    'alias': 'hylan-diner-staten-island',
#    'name': 'Hylan Diner',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y0ZuUdKx_KuGNWGeJjp6Tw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hylan-diner-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 96,
#    'categories': [{'alias': 'diners', 'title': 'Diners'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.56915, 'longitude': -74.11156},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2561 Hylan Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2561 Hylan Blvd', 'Staten Island, NY 10306']},
#    'phone': '+17186689200',
#    'display_phone': '(718) 668-9200',
#    'distance': 268.96510828939927},
#   {'id': 'RSQeWL6CWU7ji6tcqAiXEA',
#    'alias': 'better-gourmet-health-kitchen-staten-island-2',
#    'name': 'Better Gourmet Health Kitchen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/yNipBxXhFfjqzEa3nMcrGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/better-gourmet-health-kitchen-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 58,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.57425, 'longitude': -74.106426},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2333 Hylan Blvd',
#     'address2': None,
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2333 Hylan Blvd', 'Staten Island, NY 10306']},
#    'phone': '+17186680400',
#    'display_phone': '(718) 668-0400',
#    'distance': 656.1998509680686},
#   {'id': 'fsZIYlkhLbZjUpqQtjGeHQ',
#    'alias': 'canlons-restaurant-staten-island',
#    'name': "Canlon's Restaurant",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/plEHye96j5lWH_tBA2m9wQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/canlons-restaurant-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 76,
#    'categories': [{'alias': 'tradamerican',
#      'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.565179, 'longitude': -74.126835},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1825 N Railroad Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1825 N Railroad Ave', 'Staten Island, NY 10306']},
#    'phone': '+17186673013',
#    'display_phone': '(718) 667-3013',
#    'distance': 1356.5405525370807},
#   {'id': 'fxjygBjQqWSE71Ref2s0oA',
#    'alias': 'michaels-martinis-and-meatballs-staten-island',
#    'name': "Michael's Martinis & Meatballs",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DBfQZum2kXFVKSsjeK7aRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/michaels-martinis-and-meatballs-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 228,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.584706, 'longitude': -74.093654},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1816 Hylan Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10305',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1816 Hylan Blvd', 'Staten Island, NY 10305']},
#    'phone': '+13476958160',
#    'display_phone': '(347) 695-8160',
#    'distance': 2199.783835856638},
#   {'id': 'V4CgzKda_7bTqa3UTuRFCw',
#    'alias': 'avocado-sushi-staten-island-2',
#    'name': 'Avocado Sushi',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/p_p4aR6BeuDGTTfNd1LxqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/avocado-sushi-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 70,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.582986, 'longitude': -74.097047},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1919 Hylan Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10305',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1919 Hylan Blvd', 'Staten Island, NY 10305']},
#    'phone': '+17186681400',
#    'display_phone': '(718) 668-1400',
#    'distance': 1870.393773887724},
#   {'id': 'jNhMXvGQ2WonmfXWeDoxDw',
#    'alias': 'fresh-tortillas-and-taco-staten-island-2',
#    'name': 'Fresh Tortillas & Taco',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/J7mIEFuXBdUzwlMVHBvQhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fresh-tortillas-and-taco-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 73,
#    'categories': [{'alias': 'tex-mex', 'title': 'Tex-Mex'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.5717329, 'longitude': -74.112404},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '304 New Dorp Ln',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['304 New Dorp Ln', 'Staten Island, NY 10306']},
#    'phone': '+17189796666',
#    'display_phone': '(718) 979-6666',
#    'distance': 55.83745027671269},
#   {'id': 'aJkb_Ek9iZJUKgH5-cu7wQ',
#    'alias': 'nori-sushi-staten-island',
#    'name': 'Nori Sushi',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/uqfOZGj4a7D9BRF7b1IH5w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nori-sushi-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 87,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.5738067626953,
#     'longitude': -74.1175994873047},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '55 New Dorp Plz',
#     'address2': None,
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 New Dorp Plz', 'Staten Island, NY 10306']},
#    'phone': '+17186680288',
#    'display_phone': '(718) 668-0288',
#    'distance': 465.75064634089233},
#   {'id': 'lyKgV-M9XKm9osK6bT1a-Q',
#    'alias': 'cafe-con-pan-staten-island',
#    'name': 'Cafe Con Pan',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uFWd__n6agmJSrYEAWCEUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-con-pan-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 37,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.5737, 'longitude': -74.116305},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '32 New Dorp Plz S',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32 New Dorp Plz S', 'Staten Island, NY 10306']},
#    'phone': '+13478610364',
#    'display_phone': '(347) 861-0364',
#    'distance': 374.5182234200522},
#   {'id': 'x_ojll0Ik-UPyXnSkgFBPQ',
#    'alias': 'corner-house-bbq-staten-island',
#    'name': 'Corner House BBQ',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XJWAqZmOEJk9nXl2mX0mqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/corner-house-bbq-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 259,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.579608, 'longitude': -74.1095},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '102 Lincoln Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['102 Lincoln Ave', 'Staten Island, NY 10306']},
#    'phone': '+17189871227',
#    'display_phone': '(718) 987-1227',
#    'distance': 953.2535922070606},
#   {'id': '0xl3JnEgbA4P6KKfJYup6w',
#    'alias': 'violettes-cellar-staten-island',
#    'name': "Violette's Cellar",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Kgf4FwkjwhVuh41f2VYWBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/violettes-cellar-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 253,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'speakeasies', 'title': 'Speakeasies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.57547, 'longitude': -74.10499},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2271 Hylan Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2271 Hylan Blvd', 'Staten Island, NY 10306']},
#    'phone': '+17186505050',
#    'display_phone': '(718) 650-5050',
#    'distance': 790.6578579752085},
#   {'id': '_dhsOIr9dfCBuaAM6lX7vA',
#    'alias': 'new-china-buffet-staten-island',
#    'name': 'New China Buffet',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SczTGSaVs2YIXOe_tLJdCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-china-buffet-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 81,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.567711, 'longitude': -74.111769},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2626 Hylan Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2626 Hylan Blvd', 'Staten Island, NY 10306']},
#    'phone': '+17189873388',
#    'display_phone': '(718) 987-3388',
#    'distance': 429.26222086456187},
#   {'id': 'HsjdcO2rJ22XFyeIOVeQFg',
#    'alias': 'cafe-gourmand-staten-island',
#    'name': 'Cafe Gourmand',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qK-23u5BYXdbBL_scKa83A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-gourmand-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 23,
#    'categories': [{'alias': 'russian', 'title': 'Russian'},
#     {'alias': 'armenian', 'title': 'Armenian'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.57193, 'longitude': -74.095222},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '548 Lincoln Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['548 Lincoln Ave', 'Staten Island, NY 10306']},
#    'phone': '+17183517575',
#    'display_phone': '(718) 351-7575',
#    'distance': 1507.8070730916056},
#   {'id': 'U6kLMaDnq6tBD83U0YHshg',
#    'alias': 'fushimi-todt-hill-staten-island',
#    'name': 'Fushimi Todt Hill',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dZTZng2naMW1UABdV-7b3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fushimi-todt-hill-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 184,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.581292, 'longitude': -74.111488},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2110 Richmond Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2110 Richmond Rd', 'Staten Island, NY 10306']},
#    'phone': '+17189805300',
#    'display_phone': '(718) 980-5300',
#    'distance': 1119.0874410621886},
#   {'id': 'cZRaFlLacN5Evf7dO9pHig',
#    'alias': 'china-taste-staten-island',
#    'name': 'China Taste',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RHqpzVAm0d_a1P_FS-JaQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/china-taste-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 10,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.5848791, 'longitude': -74.093588},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '1812 Hylan Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10305',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1812 Hylan Blvd', 'Staten Island, NY 10305']},
#    'phone': '+17189875269',
#    'display_phone': '(718) 987-5269',
#    'distance': 2217.7288990206234},
#   {'id': 'lDVHKeiRdiQ2hL5nMzG49w',
#    'alias': 'jimmy-max-staten-island-3',
#    'name': 'Jimmy Max',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jimmy-max-staten-island-3?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 2,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 40.586094, 'longitude': -74.104576},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1820 Richmond Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10306',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1820 Richmond Rd', 'Staten Island, NY 10306']},
#    'phone': '+17189836715',
#    'display_phone': '(718) 983-6715',
#    'distance': 1776.1870180190972},
#   {'id': '2TOtrDhkQjaOJWwJJr0tUQ',
#    'alias': 'nakata-staten-island',
#    'name': 'Nakata',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YnjZDszdj3DkKJTCYTc3dg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nakata-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#    'review_count': 132,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.58823, 'longitude': -74.103685},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1775 D Richmond Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10304',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1775 D Richmond Rd', 'Staten Island, NY 10304']},
#    'phone': '+17189801891',
#    'display_phone': '(718) 980-1891',
#    'distance': 2024.0883339608201}],
#  'total': 55,
#  'region': {'center': {'longitude': -74.11299705505371,
#    'latitude': 40.57145704856859}}}

# %% [markdown]
# What are the keys in this dictionary and the datatypes of their values.

# %%
for key, value in data.items():
    print(key)
    print(type(value))
# Out:
# businesses
# <class 'list'>
# total
# <class 'int'>
# region
# <class 'dict'>

# %% [markdown]
# How many results did our query return?

# %%
print(data['total'])
print(len(data['businesses']))
# Out:
# 55
# 50

# %% [markdown]
# How many businesses were returned from the API call?

# %%
data['businesses']
# Out:
# [{'id': 'LlT5XLc88hFDcWiCKskasg',
#   'alias': 'pizzeria-giove-staten-island',
#   'name': 'Pizzeria Giove',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/w-Ne6LJLVLnmJlJJBazRsA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pizzeria-giove-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 307,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.57215, 'longitude': -74.1131599},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '278 New Dorp Ln',
#    'address2': '',
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['278 New Dorp Ln', 'Staten Island, NY 10306']},
#   'phone': '+13472860635',
#   'display_phone': '(347) 286-0635',
#   'distance': 75.34648018324394},
#  {'id': 'eendqrZ9Cp_JisaDtoBU4w',
#   'alias': 'bravo-pizza-staten-island',
#   'name': 'Bravo Pizza',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/98GIefvXOn22c6qrv3ebMQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bravo-pizza-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 11,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.5701278126894, 'longitude': -74.108795389156},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '413  New Dorp Ln',
#    'address2': '',
#    'address3': None,
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['413  New Dorp Ln', 'Staten Island, NY 10306']},
#   'phone': '+17183171010',
#   'display_phone': '(718) 317-1010',
#   'distance': 384.43767528529156},
#  {'id': '-jdadX3fGXA2TDapnufYFA',
#   'alias': 'dough-by-licastri-staten-island',
#   'name': 'DOUGH By Licastri',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eHIjhfgelm1nBhir7Rq_-w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/dough-by-licastri-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 131,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.59391, 'longitude': -74.09948},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1456 Richmond Rd',
#    'address2': None,
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10304',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1456 Richmond Rd', 'Staten Island, NY 10304']},
#   'phone': '+17186681600',
#   'display_phone': '(718) 668-1600',
#   'distance': 2744.5071665458286},
#  {'id': '2NBbuLr9JWEzfbvML83Dkg',
#   'alias': 'giacomos-pizzeria-staten-island',
#   'name': 'Giacomos Pizzeria',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tUNTsQo16oggOlR_OpHejQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/giacomos-pizzeria-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 34,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.57326, 'longitude': -74.11522},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '170 New Dorp Ln',
#    'address2': '',
#    'address3': None,
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['170 New Dorp Ln', 'Staten Island, NY 10306']},
#   'phone': '+17186680490',
#   'display_phone': '(718) 668-0490',
#   'distance': 271.76136780900123},
#  {'id': 'Chaq0plYdKIILsAfAFvwBA',
#   'alias': 'nunzios-pizzeria-and-restaurant-staten-island',
#   'name': "Nunzio's Pizzeria & Restaurant",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/upT_UvNekVt8LQPckOVWQw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/nunzios-pizzeria-and-restaurant-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 109,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.57799, 'longitude': -74.10271},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '2155 Hylan Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2155 Hylan Blvd', 'Staten Island, NY 10306']},
#   'phone': '+17186679647',
#   'display_phone': '(718) 667-9647',
#   'distance': 1132.1659743860528},
#  {'id': 'U0HmnNv1wJL-dANj_Dq71A',
#   'alias': 'lees-tavern-staten-island',
#   'name': "Lee's Tavern",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XzJqQB18-UeZaeWrsHyyGg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lees-tavern-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 498,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'pubs', 'title': 'Pubs'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.588756, 'longitude': -74.095153},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '60 Hancock St',
#    'address2': '',
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10305',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['60 Hancock St', 'Staten Island, NY 10305']},
#   'phone': '+17186679749',
#   'display_phone': '(718) 667-9749',
#   'distance': 2443.1955234493444},
#  {'id': 'yWGdfTjzk0KDjrUpUan5vA',
#   'alias': 'prime-pizza-kitchen-staten-island',
#   'name': 'Prime Pizza Kitchen',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_TimNJnhQIAwyYrQK59vEw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/prime-pizza-kitchen-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 47,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.5853249350922,
#    'longitude': -74.0926520634632},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '1778 Hylan Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10305',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1778 Hylan Blvd', 'Staten Island, NY 10305']},
#   'phone': '+17183515000',
#   'display_phone': '(718) 351-5000',
#   'distance': 2308.715085845923},
#  {'id': '9JFO3le5_jl5_yaC4fKLbw',
#   'alias': 'restaurant-on-the-plaza-pizzeria-staten-island',
#   'name': 'Restaurant On the Plaza Pizzeria',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QkT8bHcjs6sNdGP-GhAD0Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/restaurant-on-the-plaza-pizzeria-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 20,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.57338, 'longitude': -74.11664},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '50 New Dorp Plz',
#    'address2': '',
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['50 New Dorp Plz', 'Staten Island, NY 10306']},
#   'phone': '+17186677170',
#   'display_phone': '(718) 667-7170',
#   'distance': 386.15973125965326},
#  {'id': '-m8hYUDP6howLkVkEzBGSg',
#   'alias': 'pronto-pizza-staten-island-3',
#   'name': 'Pronto Pizza',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_gkJFPtrnC6sxZ9mntUC0A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pronto-pizza-staten-island-3?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 49,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 40.57147, 'longitude': -74.1111},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '337 New Dorp Ln',
#    'address2': None,
#    'address3': None,
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['337 New Dorp Ln', 'Staten Island, NY 10306']},
#   'phone': '+17183512700',
#   'display_phone': '(718) 351-2700',
#   'distance': 157.99406266087638},
#  {'id': '461hss6jSwjN8FdiZgN6wA',
#   'alias': 'the-original-goodfellas-brick-oven-pizza-staten-island-2',
#   'name': "The Original Goodfella's Brick Oven Pizza",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6DQT6mdKn05HGmDapqlRgA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-original-goodfellas-brick-oven-pizza-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 246,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.586785, 'longitude': -74.091438},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1718 Hylan Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10305',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1718 Hylan Blvd', 'Staten Island, NY 10305']},
#   'phone': '+17189872422',
#   'display_phone': '(718) 987-2422',
#   'distance': 2493.9961938672122},
#  {'id': 'iPLXtSD442PQXnlC5jAqbg',
#   'alias': 'cucina-fresca-staten-island-2',
#   'name': 'Cucina Fresca',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Q5W4Q6JvpSSe4CNInCywLw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cucina-fresca-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 88,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.581292, 'longitude': -74.111488},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '2110 Richmond Rd',
#    'address2': 'Ste 6',
#    'address3': None,
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2110 Richmond Rd',
#     'Ste 6',
#     'Staten Island, NY 10306']},
#   'phone': '+17186675152',
#   'display_phone': '(718) 667-5152',
#   'distance': 1119.0874410621886},
#  {'id': 'SNX8DPWkqhPDYnw2k0QUGA',
#   'alias': 'ny-family-pizza-staten-island',
#   'name': 'NY Family Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VGMMqzvV1j7SwFb9gsza_g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ny-family-pizza-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 16,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.58329, 'longitude': -74.095077},
#   'transactions': [],
#   'location': {'address1': '1880 Hylan Blvd',
#    'address2': '',
#    'address3': None,
#    'city': 'Staten Island',
#    'zip_code': '10305',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1880 Hylan Blvd', 'Staten Island, NY 10305']},
#   'phone': '+17189877000',
#   'display_phone': '(718) 987-7000',
#   'distance': 2005.4323725744332},
#  {'id': 'OBz9S_wgdXKxIX1CbU41Lw',
#   'alias': 'cuzzin-joes-pizza-staten-island',
#   'name': 'Cuzzin Joes Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2okReqJ2-fLzElfKVW7gww/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cuzzin-joes-pizza-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 3,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 40.572232, 'longitude': -74.093347},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '572 Midland Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['572 Midland Ave', 'Staten Island, NY 10306']},
#   'phone': '+17183519333',
#   'display_phone': '(718) 351-9333',
#   'distance': 1660.9745970802119},
#  {'id': 'lnY_TfGOGeRs00tHIi0T1w',
#   'alias': 'via-napoli-staten-island-2',
#   'name': 'Via Napoli',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hRvF9v4cXbaxVVyvojYBjQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/via-napoli-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 68,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 40.56743, 'longitude': -74.11138},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '2626 Hylan Blvd',
#    'address2': None,
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2626 Hylan Blvd', 'Staten Island, NY 10306']},
#   'phone': '+17186678599',
#   'display_phone': '(718) 667-8599',
#   'distance': 462.2399838771992},
#  {'id': 'wvXF3ESpaU9ly_er_DEzxQ',
#   'alias': 'ambrosinos-pizzeria-staten-island',
#   'name': "Ambrosino's Pizzeria",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DtvBxYwRyuoFwr6376EqKw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ambrosinos-pizzeria-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 35,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.564278, 'longitude': -74.133473},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '3161 Amboy Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['3161 Amboy Rd', 'Staten Island, NY 10306']},
#   'phone': '+17189878800',
#   'display_phone': '(718) 987-8800',
#   'distance': 1904.8873603938653},
#  {'id': 'P2C2U2LRC-POjGClJMKr6A',
#   'alias': 'domenicos-pizza-staten-island-51',
#   'name': "Domenico's Pizza",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ARBdRD6drM4wdAFJkz3MQQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/domenicos-pizza-staten-island-51?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 58,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.561036, 'longitude': -74.135384},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '3295 Amboy Rd',
#    'address2': 'Ste 3',
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['3295 Amboy Rd', 'Ste 3', 'Staten Island, NY 10306']},
#   'phone': '+17183512100',
#   'display_phone': '(718) 351-2100',
#   'distance': 2217.8109660697214},
#  {'id': 'GoODm3ptRYL964UeYbKPkQ',
#   'alias': 'justinos-pizzeria-staten-island',
#   'name': "Justino's Pizzeria",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Y_frBA2b-T7uga_3wAmrfg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/justinos-pizzeria-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 48,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 40.5649, 'longitude': -74.12772},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '89 Guyon Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['89 Guyon Ave', 'Staten Island, NY 10306']},
#   'phone': '+17186682020',
#   'display_phone': '(718) 668-2020',
#   'distance': 1439.7485565451568},
#  {'id': 'VAi8d2WDjjKN7saJ2rNRHg',
#   'alias': 'classic-pizza-staten-island-2',
#   'name': 'Classic Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zAkUlUzbEYob2_6PMpKjGQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/classic-pizza-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 21,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.575512, 'longitude': -74.127824},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '3201 Richmond Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['3201 Richmond Rd', 'Staten Island, NY 10306']},
#   'phone': '+17189872500',
#   'display_phone': '(718) 987-2500',
#   'distance': 1338.548091147004},
#  {'id': 'q4CBRjGixsHaK0Abm-byNw',
#   'alias': 'panino-rustico-staten-island-staten-island',
#   'name': 'Panino Rustico - Staten Island',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/V7jJEWJv1fbguORCb7GwuQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/panino-rustico-staten-island-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 91,
#   'categories': [{'alias': 'creperies', 'title': 'Creperies'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.58129, 'longitude': -74.11149},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2110 Richmond Rd',
#    'address2': '',
#    'address3': None,
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2110 Richmond Rd', 'Staten Island, NY 10306']},
#   'phone': '+17183510100',
#   'display_phone': '(718) 351-0100',
#   'distance': 1119.0874410621886},
#  {'id': 'lDz5EIOmtua_tl-UcY78wA',
#   'alias': 'sharkeys-square-pizza-staten-island',
#   'name': "Sharkey's Square Pizza",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LaqmQn2wE3W8oT74hNi7iA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sharkeys-square-pizza-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 48,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 40.5827865600586,
#    'longitude': -74.0960235595703},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '1910 Hylan Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10305',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1910 Hylan Blvd', 'Staten Island, NY 10305']},
#   'phone': '+17189794700',
#   'display_phone': '(718) 979-4700',
#   'distance': 1908.5896701189322},
#  {'id': 'pncElrotZZCTr_l1bWtB6w',
#   'alias': 'torino-cafe-staten-island-2',
#   'name': 'Torino Cafe',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/11ZcXncCmK4gJ8O4Y2mDyw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/torino-cafe-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 16,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'cafes', 'title': 'Cafes'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.58882, 'longitude': -74.1018},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1694 Richmond Rd',
#    'address2': None,
#    'address3': None,
#    'city': 'Staten Island',
#    'zip_code': '10304',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1694 Richmond Rd', 'Staten Island, NY 10304']},
#   'phone': '+17183513100',
#   'display_phone': '(718) 351-3100',
#   'distance': 2147.9663213616604},
#  {'id': 'eMMF_kyHQIrX_An67wYcpA',
#   'alias': 'griffs-place-new-dorp-beach',
#   'name': "Griff's Place",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/I3ZxAUjOWHtRcE8p5PQ4SQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/griffs-place-new-dorp-beach?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 61,
#   'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'desserts', 'title': 'Desserts'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.5656772, 'longitude': -74.100421},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '704 New Dorp Ln',
#    'address2': '',
#    'address3': '',
#    'city': 'New Dorp Beach',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['704 New Dorp Ln', 'New Dorp Beach, NY 10306']},
#   'phone': '+17186682645',
#   'display_phone': '(718) 668-2645',
#   'distance': 1232.371971624808},
#  {'id': 'KMLT72-bHysWDTqbzunhDw',
#   'alias': 'little-italy-gourmet-staten-island',
#   'name': 'Little Italy Gourmet',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/sBl_b4UGrno-QbUBhAwR4w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/little-italy-gourmet-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 25,
#   'categories': [{'alias': 'intlgrocery', 'title': 'International Grocery'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.57489, 'longitude': -74.116065},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1375 N Railroad Ave',
#    'address2': None,
#    'address3': None,
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1375 N Railroad Ave', 'Staten Island, NY 10306']},
#   'phone': '+17189803663',
#   'display_phone': '(718) 980-3663',
#   'distance': 460.2778480603174},
#  {'id': 'lr0M6lCGZPzijNlHz3ZGsA',
#   'alias': 'kim-cooks-and-caters-staten-island',
#   'name': 'Kim Cooks & Caters',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/54vGCyMXlZdZ57eyEukkaA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kim-cooks-and-caters-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 16,
#   'categories': [{'alias': 'catering', 'title': 'Caterers'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.579906, 'longitude': -74.109256},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '97 Lincoln Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['97 Lincoln Ave', 'Staten Island, NY 10306']},
#   'phone': '+12124252623',
#   'display_phone': '(212) 425-2623',
#   'distance': 992.3150623690841},
#  {'id': 'kE0nfIY9l_guZTo8AlfHeg',
#   'alias': 'fresh-twist-juicebar-and-cafe-staten-island',
#   'name': 'Fresh Twist juicebar & cafe',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/eXWAVjrq57L89p2qU6kmow/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fresh-twist-juicebar-and-cafe-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 58,
#   'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#    {'alias': 'empanadas', 'title': 'Empanadas'},
#    {'alias': 'salad', 'title': 'Salad'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.5753893, 'longitude': -74.1192837},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '10 New Dorp Ln',
#    'address2': None,
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['10 New Dorp Ln', 'Staten Island, NY 10306']},
#   'phone': '+19178301644',
#   'display_phone': '(917) 830-1644',
#   'distance': 719.9921010341428},
#  {'id': 'iXfgnXG-LKT5R0ZlUbSHlA',
#   'alias': 'papa-johns-pizza-staten-island-2',
#   'name': "Papa John's Pizza",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cRJxEZWBnTemsiXlzPfqBw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/papa-johns-pizza-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 15,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 1.5,
#   'coordinates': {'latitude': 40.577494, 'longitude': -74.103382},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '2175 Hyland Blvd.',
#    'address2': None,
#    'address3': None,
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2175 Hyland Blvd.', 'Staten Island, NY 10306']},
#   'phone': '+17186673474',
#   'display_phone': '(718) 667-3474',
#   'distance': 1053.607211325036},
#  {'id': '1Xfz59j6iyGH6Z-GtSJblA',
#   'alias': 'how-greek-it-is-staten-island',
#   'name': 'How Greek It Is',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SkP80p8TRthZr2F3zBW6Fg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/how-greek-it-is-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 126,
#   'categories': [{'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.5760758, 'longitude': -74.1033838},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2224 Hylan Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2224 Hylan Blvd', 'Staten Island, NY 10306']},
#   'phone': '+17182733200',
#   'display_phone': '(718) 273-3200',
#   'distance': 960.7326315037509},
#  {'id': 'SNTBdiEi55Zvt3qa4AAEJg',
#   'alias': 'sakana-sushi-and-hibachi-steakhouse-staten-island',
#   'name': 'Sakana Sushi & Hibachi Steakhouse',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2A3iBAhvVfunyW8L8KmZGQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sakana-sushi-and-hibachi-steakhouse-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 13,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.589737938998, 'longitude': -74.1013584556552},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1657 Richmond Rd',
#    'address2': None,
#    'address3': None,
#    'city': 'Staten Island',
#    'zip_code': '10304',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1657 Richmond Rd', 'Staten Island, NY 10304']},
#   'phone': '+17189877999',
#   'display_phone': '(718) 987-7999',
#   'distance': 2257.9015355717625},
#  {'id': 'ewJTFUjPEOVkYj4FUm-11g',
#   'alias': 'piece-a-cake-new-york-3',
#   'name': 'Piece A Cake',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/26P2aTHH7eOBo12HB034vA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/piece-a-cake-new-york-3?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 305,
#   'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.5734755325581,
#    'longitude': -74.1147970675453},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '177 New Dorp Ln',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['177 New Dorp Ln', 'New York, NY 10306']},
#   'phone': '+17189802253',
#   'display_phone': '(718) 980-2253',
#   'distance': 271.08917154365884},
#  {'id': 'uteLxmXMOtfUhfBL9sbrLw',
#   'alias': 'subway-staten-island-40',
#   'name': 'Subway',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IaxHQVq3lJWBDgHN55D98w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/subway-staten-island-40?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 3,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 40.5645129124965,
#    'longitude': -74.1280255469758},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '86 Guyon Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['86 Guyon Ave', 'Staten Island, NY 10306']},
#   'phone': '+17185244097',
#   'display_phone': '(718) 524-4097',
#   'distance': 1485.813345486533},
#  {'id': 'thQq8A9RooELqu9_74EZRQ',
#   'alias': 'five-guys-staten-island-3',
#   'name': 'Five Guys',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/c0_6QNr0fnMAhZtJ7OOEWQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/five-guys-staten-island-3?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 21,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 40.56534, 'longitude': -74.11447},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '2754 Hylan Blvd',
#    'address2': None,
#    'address3': None,
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2754 Hylan Blvd', 'Staten Island, NY 10306']},
#   'phone': '+19175882281',
#   'display_phone': '(917) 588-2281',
#   'distance': 869.6758159361835},
#  {'id': 'ySEJ0axD_lSfsAMOApAh4Q',
#   'alias': 'brioso-staten-island',
#   'name': 'Brioso',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Sf3WJr1oCM9AKApTonGojQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/brioso-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 79,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.573052, 'longitude': -74.115113},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '174 New Dorp Ln',
#    'address2': '',
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['174 New Dorp Ln', 'Staten Island, NY 10306']},
#   'phone': '+17186671700',
#   'display_phone': '(718) 667-1700',
#   'distance': 251.77950670146038},
#  {'id': 'JdpT_5liovYNXRlQaHLHMg',
#   'alias': 'darios-pizzeria-staten-island',
#   'name': "Dario's Pizzeria",
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/darios-pizzeria-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 1,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.58129, 'longitude': -74.11149},
#   'transactions': [],
#   'location': {'address1': '2110 Richmond Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2110 Richmond Rd', 'Staten Island, NY 10306']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 1119.0874410621886},
#  {'id': 'sXxpqjRajbspzLRdv_6QBw',
#   'alias': 'simple-asia-staten-island',
#   'name': 'Simple Asia',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/msMpN2X9dRGO96gwIGzM2w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/simple-asia-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 120,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'ramen', 'title': 'Ramen'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.5746530841284,
#    'longitude': -74.1058338806033},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '2333 Hylan Blvd',
#    'address2': None,
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2333 Hylan Blvd', 'Staten Island, NY 10306']},
#   'phone': '+17189798868',
#   'display_phone': '(718) 979-8868',
#   'distance': 701.664367103952},
#  {'id': 'YDorQeInbcXaOq_fVY0-VA',
#   'alias': 'hylan-diner-staten-island',
#   'name': 'Hylan Diner',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y0ZuUdKx_KuGNWGeJjp6Tw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hylan-diner-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 96,
#   'categories': [{'alias': 'diners', 'title': 'Diners'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 40.56915, 'longitude': -74.11156},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2561 Hylan Blvd',
#    'address2': '',
#    'address3': None,
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2561 Hylan Blvd', 'Staten Island, NY 10306']},
#   'phone': '+17186689200',
#   'display_phone': '(718) 668-9200',
#   'distance': 268.96510828939927},
#  {'id': 'RSQeWL6CWU7ji6tcqAiXEA',
#   'alias': 'better-gourmet-health-kitchen-staten-island-2',
#   'name': 'Better Gourmet Health Kitchen',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/yNipBxXhFfjqzEa3nMcrGQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/better-gourmet-health-kitchen-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 58,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.57425, 'longitude': -74.106426},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2333 Hylan Blvd',
#    'address2': None,
#    'address3': None,
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2333 Hylan Blvd', 'Staten Island, NY 10306']},
#   'phone': '+17186680400',
#   'display_phone': '(718) 668-0400',
#   'distance': 656.1998509680686},
#  {'id': 'fsZIYlkhLbZjUpqQtjGeHQ',
#   'alias': 'canlons-restaurant-staten-island',
#   'name': "Canlon's Restaurant",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/plEHye96j5lWH_tBA2m9wQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/canlons-restaurant-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 76,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.565179, 'longitude': -74.126835},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1825 N Railroad Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1825 N Railroad Ave', 'Staten Island, NY 10306']},
#   'phone': '+17186673013',
#   'display_phone': '(718) 667-3013',
#   'distance': 1356.5405525370807},
#  {'id': 'fxjygBjQqWSE71Ref2s0oA',
#   'alias': 'michaels-martinis-and-meatballs-staten-island',
#   'name': "Michael's Martinis & Meatballs",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DBfQZum2kXFVKSsjeK7aRw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/michaels-martinis-and-meatballs-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 228,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.584706, 'longitude': -74.093654},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1816 Hylan Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10305',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1816 Hylan Blvd', 'Staten Island, NY 10305']},
#   'phone': '+13476958160',
#   'display_phone': '(347) 695-8160',
#   'distance': 2199.783835856638},
#  {'id': 'V4CgzKda_7bTqa3UTuRFCw',
#   'alias': 'avocado-sushi-staten-island-2',
#   'name': 'Avocado Sushi',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/p_p4aR6BeuDGTTfNd1LxqQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/avocado-sushi-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 70,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.582986, 'longitude': -74.097047},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '1919 Hylan Blvd',
#    'address2': None,
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10305',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1919 Hylan Blvd', 'Staten Island, NY 10305']},
#   'phone': '+17186681400',
#   'display_phone': '(718) 668-1400',
#   'distance': 1870.393773887724},
#  {'id': 'jNhMXvGQ2WonmfXWeDoxDw',
#   'alias': 'fresh-tortillas-and-taco-staten-island-2',
#   'name': 'Fresh Tortillas & Taco',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/J7mIEFuXBdUzwlMVHBvQhw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fresh-tortillas-and-taco-staten-island-2?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 73,
#   'categories': [{'alias': 'tex-mex', 'title': 'Tex-Mex'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.5717329, 'longitude': -74.112404},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '304 New Dorp Ln',
#    'address2': '',
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['304 New Dorp Ln', 'Staten Island, NY 10306']},
#   'phone': '+17189796666',
#   'display_phone': '(718) 979-6666',
#   'distance': 55.83745027671269},
#  {'id': 'aJkb_Ek9iZJUKgH5-cu7wQ',
#   'alias': 'nori-sushi-staten-island',
#   'name': 'Nori Sushi',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/uqfOZGj4a7D9BRF7b1IH5w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/nori-sushi-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 87,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.5738067626953,
#    'longitude': -74.1175994873047},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '55 New Dorp Plz',
#    'address2': None,
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['55 New Dorp Plz', 'Staten Island, NY 10306']},
#   'phone': '+17186680288',
#   'display_phone': '(718) 668-0288',
#   'distance': 465.75064634089233},
#  {'id': 'lyKgV-M9XKm9osK6bT1a-Q',
#   'alias': 'cafe-con-pan-staten-island',
#   'name': 'Cafe Con Pan',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uFWd__n6agmJSrYEAWCEUg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cafe-con-pan-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 37,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'bakeries', 'title': 'Bakeries'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.5737, 'longitude': -74.116305},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '32 New Dorp Plz S',
#    'address2': '',
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['32 New Dorp Plz S', 'Staten Island, NY 10306']},
#   'phone': '+13478610364',
#   'display_phone': '(347) 861-0364',
#   'distance': 374.5182234200522},
#  {'id': 'x_ojll0Ik-UPyXnSkgFBPQ',
#   'alias': 'corner-house-bbq-staten-island',
#   'name': 'Corner House BBQ',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XJWAqZmOEJk9nXl2mX0mqA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/corner-house-bbq-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 259,
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.579608, 'longitude': -74.1095},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '102 Lincoln Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['102 Lincoln Ave', 'Staten Island, NY 10306']},
#   'phone': '+17189871227',
#   'display_phone': '(718) 987-1227',
#   'distance': 953.2535922070606},
#  {'id': '0xl3JnEgbA4P6KKfJYup6w',
#   'alias': 'violettes-cellar-staten-island',
#   'name': "Violette's Cellar",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Kgf4FwkjwhVuh41f2VYWBQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/violettes-cellar-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 253,
#   'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#    {'alias': 'speakeasies', 'title': 'Speakeasies'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.57547, 'longitude': -74.10499},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2271 Hylan Blvd',
#    'address2': None,
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2271 Hylan Blvd', 'Staten Island, NY 10306']},
#   'phone': '+17186505050',
#   'display_phone': '(718) 650-5050',
#   'distance': 790.6578579752085},
#  {'id': '_dhsOIr9dfCBuaAM6lX7vA',
#   'alias': 'new-china-buffet-staten-island',
#   'name': 'New China Buffet',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SczTGSaVs2YIXOe_tLJdCA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/new-china-buffet-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 81,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'buffets', 'title': 'Buffets'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 40.567711, 'longitude': -74.111769},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '2626 Hylan Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2626 Hylan Blvd', 'Staten Island, NY 10306']},
#   'phone': '+17189873388',
#   'display_phone': '(718) 987-3388',
#   'distance': 429.26222086456187},
#  {'id': 'HsjdcO2rJ22XFyeIOVeQFg',
#   'alias': 'cafe-gourmand-staten-island',
#   'name': 'Cafe Gourmand',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qK-23u5BYXdbBL_scKa83A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cafe-gourmand-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 23,
#   'categories': [{'alias': 'russian', 'title': 'Russian'},
#    {'alias': 'armenian', 'title': 'Armenian'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.57193, 'longitude': -74.095222},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '548 Lincoln Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['548 Lincoln Ave', 'Staten Island, NY 10306']},
#   'phone': '+17183517575',
#   'display_phone': '(718) 351-7575',
#   'distance': 1507.8070730916056},
#  {'id': 'U6kLMaDnq6tBD83U0YHshg',
#   'alias': 'fushimi-todt-hill-staten-island',
#   'name': 'Fushimi Todt Hill',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dZTZng2naMW1UABdV-7b3Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fushimi-todt-hill-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 184,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'lounges', 'title': 'Lounges'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.581292, 'longitude': -74.111488},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2110 Richmond Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2110 Richmond Rd', 'Staten Island, NY 10306']},
#   'phone': '+17189805300',
#   'display_phone': '(718) 980-5300',
#   'distance': 1119.0874410621886},
#  {'id': 'cZRaFlLacN5Evf7dO9pHig',
#   'alias': 'china-taste-staten-island',
#   'name': 'China Taste',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RHqpzVAm0d_a1P_FS-JaQQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/china-taste-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 10,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 40.5848791, 'longitude': -74.093588},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '1812 Hylan Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10305',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1812 Hylan Blvd', 'Staten Island, NY 10305']},
#   'phone': '+17189875269',
#   'display_phone': '(718) 987-5269',
#   'distance': 2217.7288990206234},
#  {'id': 'lDVHKeiRdiQ2hL5nMzG49w',
#   'alias': 'jimmy-max-staten-island-3',
#   'name': 'Jimmy Max',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jimmy-max-staten-island-3?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 2,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 2.0,
#   'coordinates': {'latitude': 40.586094, 'longitude': -74.104576},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1820 Richmond Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10306',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1820 Richmond Rd', 'Staten Island, NY 10306']},
#   'phone': '+17189836715',
#   'display_phone': '(718) 983-6715',
#   'distance': 1776.1870180190972},
#  {'id': '2TOtrDhkQjaOJWwJJr0tUQ',
#   'alias': 'nakata-staten-island',
#   'name': 'Nakata',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YnjZDszdj3DkKJTCYTc3dg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/nakata-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#   'review_count': 132,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.58823, 'longitude': -74.103685},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1775 D Richmond Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10304',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1775 D Richmond Rd', 'Staten Island, NY 10304']},
#   'phone': '+17189801891',
#   'display_phone': '(718) 980-1891',
#   'distance': 2024.0883339608201}]

# %% [markdown]
# ### Parsing the Results
#
# There are a lot of key-value pairs for each business. Many of which we do not care about. Let's create a simple parser of this data that will return a list with the name, display_address, and one other data point of your choice. First we want to assign one of the businesses to the `business` variable. Once we cna properly parse oonne business  we can use a loop to do them all.

# %%
business = data['businesses'][6]

# %%
business
# Out:
# {'id': 'yWGdfTjzk0KDjrUpUan5vA',
#  'alias': 'prime-pizza-kitchen-staten-island',
#  'name': 'Prime Pizza Kitchen',
#  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_TimNJnhQIAwyYrQK59vEw/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/prime-pizza-kitchen-staten-island?adjust_creative=-uqWDK-AroyJM7jqJ5zP8Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-uqWDK-AroyJM7jqJ5zP8Q',
#  'review_count': 47,
#  'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#  'rating': 4.0,
#  'coordinates': {'latitude': 40.5853249350922, 'longitude': -74.0926520634632},
#  'transactions': ['pickup', 'delivery'],
#  'price': '$',
#  'location': {'address1': '1778 Hylan Blvd',
#   'address2': '',
#   'address3': '',
#   'city': 'Staten Island',
#   'zip_code': '10305',
#   'country': 'US',
#   'state': 'NY',
#   'display_address': ['1778 Hylan Blvd', 'Staten Island, NY 10305']},
#  'phone': '+17183515000',
#  'display_phone': '(718) 351-5000',
#  'distance': 2308.715085845923}

# %% [markdown]
# Rember we want the following pieces of information:
# name, display_address, and one other data point of your choice

# %%
biz_list = (business['name'], 
            ', '.join(business['location']['display_address']), 
            business['rating'])

# %%
biz_list
# Out:
# ('Prime Pizza Kitchen', '1778 Hylan Blvd, Staten Island, NY 10305', 4.0)

# %% [markdown]
# Now that we know how to do this for one business. Let create a function that recieves the list of businesses and returns a list of tuples with the important information.

# %%
def parse_data(list_of_data):
    # create a container to hold our parsed data
    parsed_data = []
    
    # loop through our business and parse each individual business
    for business in list_of_data:
        print(business['name'])
        biz_list = [business['name'], 
            ', '.join(business['location']['display_address']), 
            business['rating']]
    # in the loop, add each individual parsed  business to our data container
        parsed_data.append(biz_list)

    # return the container with all of the parsed results
    return parsed_data

# %%
parse_data(data['businesses'])
# Out:
# Pizzeria Giove
# Bravo Pizza
# DOUGH By Licastri
# Giacomos Pizzeria
# Nunzio's Pizzeria & Restaurant
# Lee's Tavern
# Prime Pizza Kitchen
# Restaurant On the Plaza Pizzeria
# Pronto Pizza
# The Original Goodfella's Brick Oven Pizza
# Cucina Fresca
# NY Family Pizza
# Cuzzin Joes Pizza
# Via Napoli
# Ambrosino's Pizzeria
# Domenico's Pizza
# Justino's Pizzeria
# Classic Pizza
# Panino Rustico - Staten Island
# Sharkey's Square Pizza
# Torino Cafe
# Griff's Place
# Little Italy Gourmet
# Kim Cooks & Caters
# Fresh Twist juicebar & cafe
# Papa John's Pizza
# How Greek It Is
# Sakana Sushi & Hibachi Steakhouse
# Piece A Cake
# Subway
# Five Guys
# Brioso
# Dario's Pizzeria
# Simple Asia
# Hylan Diner
# Better Gourmet Health Kitchen
# Canlon's Restaurant
# Michael's Martinis & Meatballs
# Avocado Sushi
# Fresh Tortillas & Taco
# Nori Sushi
# Cafe Con Pan
# Corner House BBQ
# Violette's Cellar
# New China Buffet
# Cafe Gourmand
# Fushimi Todt Hill
# China Taste
# Jimmy Max
# Nakata
# [['Pizzeria Giove', '278 New Dorp Ln, Staten Island, NY 10306', 4.0],
#  ['Bravo Pizza', '413  New Dorp Ln, Staten Island, NY 10306', 3.5],
#  ['DOUGH By Licastri', '1456 Richmond Rd, Staten Island, NY 10304', 4.5],
#  ['Giacomos Pizzeria', '170 New Dorp Ln, Staten Island, NY 10306', 3.5],
#  ["Nunzio's Pizzeria & Restaurant",
#   '2155 Hylan Blvd, Staten Island, NY 10306',
#   3.5],
#  ["Lee's Tavern", '60 Hancock St, Staten Island, NY 10305', 4.5],
#  ['Prime Pizza Kitchen', '1778 Hylan Blvd, Staten Island, NY 10305', 4.0],
#  ['Restaurant On the Plaza Pizzeria',
#   '50 New Dorp Plz, Staten Island, NY 10306',
#   3.5],
#  ['Pronto Pizza', '337 New Dorp Ln, Staten Island, NY 10306', 2.5],
#  ["The Original Goodfella's Brick Oven Pizza",
#   '1718 Hylan Blvd, Staten Island, NY 10305',
#   4.0],
#  ['Cucina Fresca', '2110 Richmond Rd, Ste 6, Staten Island, NY 10306', 4.5],
#  ['NY Family Pizza', '1880 Hylan Blvd, Staten Island, NY 10305', 4.0],
#  ['Cuzzin Joes Pizza', '572 Midland Ave, Staten Island, NY 10306', 2.5],
#  ['Via Napoli', '2626 Hylan Blvd, Staten Island, NY 10306', 3.0],
#  ["Ambrosino's Pizzeria", '3161 Amboy Rd, Staten Island, NY 10306', 3.5],
#  ["Domenico's Pizza", '3295 Amboy Rd, Ste 3, Staten Island, NY 10306', 3.5],
#  ["Justino's Pizzeria", '89 Guyon Ave, Staten Island, NY 10306', 3.0],
#  ['Classic Pizza', '3201 Richmond Rd, Staten Island, NY 10306', 3.5],
#  ['Panino Rustico - Staten Island',
#   '2110 Richmond Rd, Staten Island, NY 10306',
#   4.5],
#  ["Sharkey's Square Pizza", '1910 Hylan Blvd, Staten Island, NY 10305', 3.0],
#  ['Torino Cafe', '1694 Richmond Rd, Staten Island, NY 10304', 3.5],
#  ["Griff's Place", '704 New Dorp Ln, New Dorp Beach, NY 10306', 4.5],
#  ['Little Italy Gourmet', '1375 N Railroad Ave, Staten Island, NY 10306', 4.5],
#  ['Kim Cooks & Caters', '97 Lincoln Ave, Staten Island, NY 10306', 4.0],
#  ['Fresh Twist juicebar & cafe',
#   '10 New Dorp Ln, Staten Island, NY 10306',
#   4.5],
#  ["Papa John's Pizza", '2175 Hyland Blvd., Staten Island, NY 10306', 1.5],
#  ['How Greek It Is', '2224 Hylan Blvd, Staten Island, NY 10306', 4.0],
#  ['Sakana Sushi & Hibachi Steakhouse',
#   '1657 Richmond Rd, Staten Island, NY 10304',
#   4.5],
#  ['Piece A Cake', '177 New Dorp Ln, New York, NY 10306', 4.0],
#  ['Subway', '86 Guyon Ave, Staten Island, NY 10306', 2.5],
#  ['Five Guys', '2754 Hylan Blvd, Staten Island, NY 10306', 2.5],
#  ['Brioso', '174 New Dorp Ln, Staten Island, NY 10306', 3.5],
#  ["Dario's Pizzeria", '2110 Richmond Rd, Staten Island, NY 10306', 4.0],
#  ['Simple Asia', '2333 Hylan Blvd, Staten Island, NY 10306', 4.5],
#  ['Hylan Diner', '2561 Hylan Blvd, Staten Island, NY 10306', 3.0],
#  ['Better Gourmet Health Kitchen',
#   '2333 Hylan Blvd, Staten Island, NY 10306',
#   3.5],
#  ["Canlon's Restaurant", '1825 N Railroad Ave, Staten Island, NY 10306', 4.0],
#  ["Michael's Martinis & Meatballs",
#   '1816 Hylan Blvd, Staten Island, NY 10305',
#   4.0],
#  ['Avocado Sushi', '1919 Hylan Blvd, Staten Island, NY 10305', 3.5],
#  ['Fresh Tortillas & Taco', '304 New Dorp Ln, Staten Island, NY 10306', 3.5],
#  ['Nori Sushi', '55 New Dorp Plz, Staten Island, NY 10306', 3.5],
#  ['Cafe Con Pan', '32 New Dorp Plz S, Staten Island, NY 10306', 3.5],
#  ['Corner House BBQ', '102 Lincoln Ave, Staten Island, NY 10306', 4.0],
#  ["Violette's Cellar", '2271 Hylan Blvd, Staten Island, NY 10306', 4.0],
#  ['New China Buffet', '2626 Hylan Blvd, Staten Island, NY 10306', 3.0],
#  ['Cafe Gourmand', '548 Lincoln Ave, Staten Island, NY 10306', 3.5],
#  ['Fushimi Todt Hill', '2110 Richmond Rd, Staten Island, NY 10306', 3.5],
#  ['China Taste', '1812 Hylan Blvd, Staten Island, NY 10305', 2.5],
#  ['Jimmy Max', '1820 Richmond Rd, Staten Island, NY 10306', 2.0],
#  ['Nakata', '1775 D Richmond Rd, Staten Island, NY 10304', 3.5]]

# %%
import pandas as pd

# %%
df = pd.DataFrame(parsed_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-193-c00aa81eac33> in <module>
# ----> 1 df = pd.DataFrame(parsed_data)
#
# NameError: name 'parsed_data' is not defined

# %%
df = pd.DataFrame()
db = pd.DataFrame([1,2,3])

# %%
dv = pd.concat([df,db])

# %%
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 0  1
# 1  2
# 2  3
