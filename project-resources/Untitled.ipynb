# %%
import requests 
import pandas as pd 
import json 
import numpy as np
import pprint

from bs4 import BeautifulSoup

# %%
api_key = 'ac80e2c89884220d09d71b0042b91aebc5f4cd1f'

# %%
url = 'https://www.gamespot.com/api/reviews/'

# %%
header = {'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36'}

# %%
url_params = {
    'api_key': api_key,
    'format': 'json',
    'limit': 100
            }
print(url_params)
# Out:
# {'api_key': 'ac80e2c89884220d09d71b0042b91aebc5f4cd1f', 'format': 'json', 'limit': 3}

# %%
response = requests.get(url,headers = header, params = url_params)
print(response.status_code)
#print(response.text)
pp = pprint.PrettyPrinter(indent=4)
res_json = json.loads(response.text)
pp.pprint(res_json)
len(res_json['results'])
# Out:
# 200
# {   'error': 'OK',
#     'limit': 3,
#     'number_of_page_results': 3,
#     'number_of_total_results': 15047,
#     'offset': 0,
#     'results': [   {   'authors': 'Jeff Sengstack',
#                        'bad': '',
#                        'body': '<p>Under a Killing Moon (UAKM) is an '
#                                'excellently wrapped package with some less '
#                                'than compelling contents.</p>  <p>You play Tex '
#                                'Murphy, the bumbling, disheveled detective '
#                                'from two previous Access adventures, Mean '
#                                'Streets and Martian Memorandum. You wander at '
#                                'will through his sharply detailed 3-D '
#                                'environment, examining objects, opening '
#                                "drawers, and talking to characters. Tex's "
#                                'gaming world is huge, ranging from his '
#                                'cluttered office and nearby dark alleys to a '
#                                'glittering mansion and a gargantuan space '
#                                "station. Your goal? Save the world. You'll "
#                                'accomplish this by exploring (high and low), '
#                                'gathering clues and items, solving typical '
#                                'adventure puzzles, and conducting interminable '
#                                'interviews. Experienced adventurers will find '
#                                'that the gaming elements are moderately '
#                                'challenging and if you do run into a brick '
#                                'wall, UAKM has an easy and effective built-in '
#                                "hint system. The game's install process sets a "
#                                'standard for ease-of-use that is thankfully '
#                                'becoming more common.  Problems arise in the '
#                                'acting and dialogue. Both are uniformly '
#                                'stilted. </p>  <p>Access hired some "name" '
#                                'actors to lend UAKM some Hollywood cachet, but '
#                                'they have only minor roles and offer less than '
#                                'stellar performances. Most of the acting was '
#                                'done by Access employees&#151;and it shows. '
#                                'Dialogue is more interruptible than '
#                                'interactive since you select questions and '
#                                'listen to responses one at a time. And the '
#                                'storyline, while complex and deep, unravels '
#                                'awkwardly. Nevertheless, the overall '
#                                'experience is entertaining and full of '
#                                'surprises. Access has created a clever '
#                                "story-telling engine; it's the ingredients "
#                                'that need work. A little more time spent on '
#                                'designing a creative story and finding '
#                                "qualified personnel to portray the game's many "
#                                'characters would have gone a long way.</p>',
#                        'deck': 'Under a Killing Moon is an excellently wrapped '
#                                'package with some less than compelling '
#                                'contents.',
#                        'game': {   'api_detail_url': 'https://www.gamespot.com/api/games/?filter=id%3A2230',
#                                    'id': 2230,
#                                    'name': 'Under a Killing Moon',
#                                    'site_detail_url': 'https://www.gamespot.com/under-a-killing-moon/'},
#                        'good': '',
#                        'id': 2531694,
#                        'image': {   'original': 'https://gamespot1.cbsistatic.com/uploads/original/469/4693985/2305502-default-art--kubrick.jpg',
#                                     'screen_tiny': 'https://gamespot1.cbsistatic.com/uploads/screen_tiny/469/4693985/2305502-default-art--kubrick.jpg',
#                                     'square_small': 'https://gamespot1.cbsistatic.com/uploads/square_small/469/4693985/2305502-default-art--kubrick.jpg',
#                                     'square_tiny': 'https://gamespot1.cbsistatic.com/uploads/square_tiny/469/4693985/2305502-default-art--kubrick.jpg'},
#                        'lede': 'Under a Killing Moon is an excellently wrapped '
#                                'package with some less than compelling '
#                                'contents.',
#                        'publish_date': '1996-05-01 12:00:00',
#                        'releases': [   {   'api_detail_url': 'https://www.gamespot.com/api/releases/?filter=id%3A8526',
#                                            'distribution_type': 'Retail',
#                                            'id': 8526,
#                                            'name': 'Under a Killing Moon',
#                                            'platform': 'PC',
#                                            'region': 'Europe',
#                                            'upc': None},
#                                        {   'api_detail_url': 'https://www.gamespot.com/api/releases/?filter=id%3A8525',
#                                            'distribution_type': 'Retail',
#                                            'id': 8525,
#                                            'name': 'Under a Killing Moon',
#                                            'platform': 'PC',
#                                            'region': 'North America',
#                                            'upc': '081192712049'}],
#                        'review_type': 'primary',
#                        'score': '6.9',
#                        'site_detail_url': 'https://www.gamespot.com/reviews/under-a-killing-moon-review/1900-2531694/',
#                        'title': 'Under a Killing Moon Review',
#                        'update_date': '1996-05-01 12:00:00'},
#                    {   'authors': 'Ron Dulin',
#                        'bad': '',
#                        'body': '<p>Blizzard Entertainment has outdone itself '
#                                'with this sequel to Warcraft: Orcs and Humans. '
#                                'The development company has become known for '
#                                'highly playable games - including cartridge '
#                                "classics like Interplay's The Lost Vikings and "
#                                'PC greats such as the side-scrolling action '
#                                'game Blackthorne - but the original Warcraft '
#                                "was the first to show Blizzard's penchant for "
#                                'strategic fare. Warcraft II: Tides of Darkness '
#                                'continues in the same vein as its predecessor, '
#                                'but adds more depth and features to the '
#                                'formula.</p>  <p>Combining the best aspects of '
#                                'many strategy favorites - Dune II, Populous '
#                                'and SimCity - Warcraft II manages to create a '
#                                'truly unique experience that considerably '
#                                'improves upon its predecessor. A plethora of '
#                                'options and features have been added to the '
#                                'real-time war game engine of the original, '
#                                'making every aspect of the game, from combat '
#                                'to resource management, much more enthralling. '
#                                'Flying vessels and seafaring crafts have been '
#                                'added, improving upon the landlocked combat of '
#                                'Warcraft. There are new technologies to '
#                                'research, new structures to build, and new '
#                                'races to align with. Resource management has '
#                                'been expanded, and now includes oil, in '
#                                'addition to gold and lumber, as a necessary '
#                                'ingredient for successful construction and '
#                                'destruction. </p>  <p>In addition to '
#                                'noticeably improved artificial intelligence, '
#                                'the most obvious change to combat is the "fog '
#                                'of war," a shroud of semi-darkness which '
#                                'allows your minions to see only what is in '
#                                'their direct line of sight. This decimates any '
#                                'fool-proof strategies that were available in '
#                                'the original; for instance, you can no longer  '
#                                'send a kamikaze scout into enemy territory, '
#                                'then watch the goings-on for the rest of the '
#                                'game. Warcraft II also gives you the option to '
#                                'command nine units at once, making large-scale '
#                                'battles much more viable and enjoyable. And as '
#                                'a complement to the drastic changes in '
#                                'gameplay, the aesthetics have been enhanced '
#                                'too, with highly-detailed SVGA graphics and a '
#                                'bombastic soundtrack that suits the regal mood '
#                                'quite nicely.</p>  <p>Perhaps the most amazing '
#                                'thing about Warcraft II, however, is that it '
#                                'takes two seemingly geek-dominated '
#                                'niches--namely war gaming and fantasy '
#                                'role-playing--and makes them incredibly fun. '
#                                "And funny. There's nothing quite as amusing as "
#                                'hearing one of your minions say, in a faux '
#                                'Shakespearean tenor, "Why do you keep touching '
#                                'me?" in the heat of battle. The only slightly '
#                                'justified complaint is that the game is too '
#                                'short as single-player fare. But the '
#                                'incredible multiplayer options (including the '
#                                'ability to have several players use one copy '
#                                'of the CD), coupled with the custom scenario '
#                                'builder and the Beyond the Dark Portal '
#                                'expansion pack, make that nit too '
#                                'insignificant to pick.</p>',
#                        'deck': 'Warcraft II manages to create a truly unique '
#                                'experience that considerably improves upon its '
#                                'predecessor.',
#                        'game': {   'api_detail_url': 'https://www.gamespot.com/api/games/?filter=id%3A2298',
#                                    'id': 2298,
#                                    'name': 'Warcraft II: Tides of Darkness',
#                                    'site_detail_url': 'https://www.gamespot.com/warcraft-ii-tides-of-darkness/'},
#                        'good': '',
#                        'id': 2531809,
#                        'image': {   'original': 'https://gamespot1.cbsistatic.com/uploads/original/469/4693985/2305502-default-art--kubrick.jpg',
#                                     'screen_tiny': 'https://gamespot1.cbsistatic.com/uploads/screen_tiny/469/4693985/2305502-default-art--kubrick.jpg',
#                                     'square_small': 'https://gamespot1.cbsistatic.com/uploads/square_small/469/4693985/2305502-default-art--kubrick.jpg',
#                                     'square_tiny': 'https://gamespot1.cbsistatic.com/uploads/square_tiny/469/4693985/2305502-default-art--kubrick.jpg'},
#                        'lede': 'Warcraft II manages to create a truly unique '
#                                'experience that considerably improves upon its '
#                                'predecessor.',
#                        'publish_date': '1996-05-01 12:00:00',
#                        'releases': [   {   'api_detail_url': 'https://www.gamespot.com/api/releases/?filter=id%3A8813',
#                                            'distribution_type': 'Retail',
#                                            'id': 8813,
#                                            'name': 'Warcraft II: Tides of '
#                                                    'Darkness (Blizzard '
#                                                    'Originals)',
#                                            'platform': 'PC',
#                                            'region': 'Europe',
#                                            'upc': None},
#                                        {   'api_detail_url': 'https://www.gamespot.com/api/releases/?filter=id%3A595403',
#                                            'distribution_type': 'Retail',
#                                            'id': 595403,
#                                            'name': 'Next 350 Levels',
#                                            'platform': 'PC',
#                                            'region': 'North America',
#                                            'upc': None},
#                                        {   'api_detail_url': 'https://www.gamespot.com/api/releases/?filter=id%3A595409',
#                                            'distribution_type': 'Retail',
#                                            'id': 595409,
#                                            'name': 'The Next 70 Levels Vol. 1',
#                                            'platform': 'PC',
#                                            'region': 'North America',
#                                            'upc': None},
#                                        {   'api_detail_url': 'https://www.gamespot.com/api/releases/?filter=id%3A593700',
#                                            'distribution_type': 'Retail',
#                                            'id': 593700,
#                                            'name': 'W!Zone',
#                                            'platform': 'Macintosh',
#                                            'region': 'North America',
#                                            'upc': None},
#                                        {   'api_detail_url': 'https://www.gamespot.com/api/releases/?filter=id%3A593701',
#                                            'distribution_type': 'Retail',
#                                            'id': 593701,
#                                            'name': 'W!Zone',
#                                            'platform': 'PC',
#                                            'region': 'North America',
#                                            'upc': None},
#                                        {   'api_detail_url': 'https://www.gamespot.com/api/releases/?filter=id%3A593702',
#                                            'distribution_type': 'Retail',
#                                            'id': 593702,
#                                            'name': 'W!Zone II Retribution',
#                                            'platform': 'PC',
#                                            'region': 'North America',
#                                            'upc': None},
#                                        {   'api_detail_url': 'https://www.gamespot.com/api/releases/?filter=id%3A8795',
#                                            'distribution_type': 'Retail',
#                                            'id': 8795,
#                                            'name': 'Warcraft II: Battle.net '
#                                                    'Edition',
#                                            'platform': 'PC',
#                                            'region': 'North America',
#                                            'upc': None},
#                                        {   'api_detail_url': 'https://www.gamespot.com/api/releases/?filter=id%3A8800',
#                                            'distribution_type': 'Retail',
#                                            'id': 8800,
#                                            'name': 'Warcraft II: Battle.net '
#                                                    'Edition',
#                                            'platform': 'Macintosh',
#                                            'region': 'North America',
#                                            'upc': None},
#                                        {   'api_detail_url': 'https://www.gamespot.com/api/releases/?filter=id%3A8799',
#                                            'distribution_type': 'Retail',
#                                            'id': 8799,
#                                            'name': 'Warcraft II: Battle.net '
#                                                    'Edition (BestSeller '
#                                                    'Series)',
#                                            'platform': 'PC',
#                                            'region': 'North America',
#                                            'upc': None},
#                                        {   'api_detail_url': 'https://www.gamespot.com/api/releases/?filter=id%3A8801',
#                                            'distribution_type': 'Retail',
#                                            'id': 8801,
#                                            'name': 'Warcraft II: Beyond the '
#                                                    'Dark Portal',
#                                            'platform': 'PC',
#                                            'region': 'North America',
#                                            'upc': '051581109361'},
#                                        {   'api_detail_url': 'https://www.gamespot.com/api/releases/?filter=id%3A8803',
#                                            'distribution_type': 'Retail',
#                                            'id': 8803,
#                                            'name': 'Warcraft II: Beyond the '
#                                                    'Dark Portal',
#                                            'platform': 'Macintosh',
#                                            'region': 'North America',
#                                            'upc': None},
#                                        {   'api_detail_url': 'https://www.gamespot.com/api/releases/?filter=id%3A705855',
#                                            'distribution_type': 'Retail',
#                                            'id': 705855,
#                                            'name': 'Warcraft II: Beyond the '
#                                                    'Dark Portal (PC only)',
#                                            'platform': 'PC',
#                                            'region': 'North America',
#                                            'upc': '051581091994'},
#                                        {   'api_detail_url': 'https://www.gamespot.com/api/releases/?filter=id%3A8807',
#                                            'distribution_type': 'Retail',
#                                            'id': 8807,
#                                            'name': 'Warcraft II: The Dark Saga',
#                                            'platform': 'PlayStation',
#                                            'region': 'North America',
#                                            'upc': '014633077957'},
#                                        {   'api_detail_url': 'https://www.gamespot.com/api/releases/?filter=id%3A8809',
#                                            'distribution_type': 'Retail',
#                                            'id': 8809,
#                                            'name': 'Warcraft II: The Dark Saga',
#                                            'platform': 'Saturn',
#                                            'region': 'North America',
#                                            'upc': '014633077964'},
#                                        {   'api_detail_url': 'https://www.gamespot.com/api/releases/?filter=id%3A8811',
#                                            'distribution_type': 'Retail',
#                                            'id': 8811,
#                                            'name': 'Warcraft II: Tides of '
#                                                    'Darkness',
#                                            'platform': 'PC',
#                                            'region': 'North America',
#                                            'upc': '051581079435'},
#                                        {   'api_detail_url': 'https://www.gamespot.com/api/releases/?filter=id%3A8814',
#                                            'distribution_type': 'Retail',
#                                            'id': 8814,
#                                            'name': 'Warcraft II: Tides of '
#                                                    'Darkness',
#                                            'platform': 'Macintosh',
#                                            'region': 'North America',
#                                            'upc': '051581094902'},
#                                        {   'api_detail_url': 'https://www.gamespot.com/api/releases/?filter=id%3A672555',
#                                            'distribution_type': 'Retail',
#                                            'id': 672555,
#                                            'name': 'Warcraft II: Tides of '
#                                                    'Darkness (Hybrid PC/Mac)',
#                                            'platform': 'Macintosh',
#                                            'region': 'North America',
#                                            'upc': '051581039606'},
#                                        {   'api_detail_url': 'https://www.gamespot.com/api/releases/?filter=id%3A672266',
#                                            'distribution_type': 'Retail',
#                                            'id': 672266,
#                                            'name': 'Warcraft II: Tides of '
#                                                    'Darkness (Re-release)',
#                                            'platform': 'PC',
#                                            'region': 'North America',
#                                            'upc': '051581039606'}],
#                        'review_type': 'primary',
#                        'score': '9.3',
#                        'site_detail_url': 'https://www.gamespot.com/reviews/warcraft-ii-tides-of-darkness-review/1900-2531809/',
#                        'title': 'Warcraft II: Tides of Darkness Review',
#                        'update_date': '2000-05-02 11:56:32'},
#                    {   'authors': 'Trent Ward',
#                        'bad': '',
#                        'body': '<p>Somewhere between an RPG and a wargame, '
#                                'Warhammer offers a refreshing change of pace '
#                                'for fans of either genre looking for a new '
#                                'play experience. Set in the fantasy world of '
#                                "Games Workshop's pen-and-paper roleplaying "
#                                'World of Warhammer, Shadow of the Horned Rat '
#                                'is a compelling adventure that gives you a '
#                                'taste of the life of a mercenary captain.</p>  '
#                                '<p>You start with a small army: a single '
#                                'cavalry and infantry unit. While you peruse a '
#                                "map of the kingdom, the company's accountant "
#                                'and paymaster details the various mercenary '
#                                'jobs currently available and how well each '
#                                "will pay. From here you'll need to select "
#                                'which forces you want to take into battle, and '
#                                'then head out to war. Choose your fights '
#                                'carefully, though; your decisions about whom '
#                                'to support will affect the way the rest of the '
#                                'game is played. As you win more battles, you '
#                                'will gain money, recruit new soldiers, make '
#                                "new friends, and, if you're observant, attain "
#                                'powerful magic items too.</p>  <p>Without '
#                                "overlooking the game's well-written plot and "
#                                "solid voice-acting and animation, it's fair to "
#                                "say that Warhammer's combat system is really "
#                                "its central feature. The game's real-time "
#                                'battles, which are challenging and addictive, '
#                                'require you to observe the land around you and '
#                                'use it tactically. Enemy AI routines are '
#                                'surprisingly realistic and will keep even '
#                                'veteran wargamers on their toes. '
#                                'Unfortunately, the entire combat system is '
#                                'complicated by a movement system that can make '
#                                'it extremely difficult to select your various '
#                                "units.</p>  <p>Warhammer's fantastic character "
#                                'development, addictive warfare system, and '
#                                'absorbing story override most of its interface '
#                                'failings, and most strategy fans will find '
#                                'this title an excellent addition to their game '
#                                'libraries. Be forewarned though: Warhammer is '
#                                'a difficult game, and those with poor tactical '
#                                'skills or little patience will most likely '
#                                'find it too challenging.</p>',
#                        'deck': 'Somewhere between an RPG and a wargame, '
#                                'Warhammer offers a refreshing change of pace '
#                                'for fans of either genre looking for a new '
#                                'play experience.',
#                        'game': {   'api_detail_url': 'https://www.gamespot.com/api/games/?filter=id%3A2304',
#                                    'id': 2304,
#                                    'name': 'Warhammer: Shadow of the Horned '
#                                            'Rat',
#                                    'site_detail_url': 'https://www.gamespot.com/warhammer-shadow-of-the-horned-rat/'},
#                        'good': '',
#                        'id': 2531824,
#                        'image': {   'original': 'https://gamespot1.cbsistatic.com/uploads/original/469/4693985/2305502-default-art--kubrick.jpg',
#                                     'screen_tiny': 'https://gamespot1.cbsistatic.com/uploads/screen_tiny/469/4693985/2305502-default-art--kubrick.jpg',
#                                     'square_small': 'https://gamespot1.cbsistatic.com/uploads/square_small/469/4693985/2305502-default-art--kubrick.jpg',
#                                     'square_tiny': 'https://gamespot1.cbsistatic.com/uploads/square_tiny/469/4693985/2305502-default-art--kubrick.jpg'},
#                        'lede': 'Somewhere between an RPG and a wargame, '
#                                'Warhammer offers a refreshing change of pace '
#                                'for fans of either genre looking for a new '
#                                'play experience.',
#                        'publish_date': '1996-05-01 12:00:00',
#                        'releases': [   {   'api_detail_url': 'https://www.gamespot.com/api/releases/?filter=id%3A8828',
#                                            'distribution_type': 'Retail',
#                                            'id': 8828,
#                                            'name': 'Warhammer: Shadow of the '
#                                                    'Horned Rat',
#                                            'platform': 'PC',
#                                            'region': 'Europe',
#                                            'upc': None},
#                                        {   'api_detail_url': 'https://www.gamespot.com/api/releases/?filter=id%3A8827',
#                                            'distribution_type': 'Retail',
#                                            'id': 8827,
#                                            'name': 'Warhammer: Shadow of the '
#                                                    'Horned Rat',
#                                            'platform': 'PC',
#                                            'region': 'North America',
#                                            'upc': None},
#                                        {   'api_detail_url': 'https://www.gamespot.com/api/releases/?filter=id%3A8830',
#                                            'distribution_type': 'Retail',
#                                            'id': 8830,
#                                            'name': 'Warhammer: Shadow of the '
#                                                    'Horned Rat',
#                                            'platform': 'PlayStation',
#                                            'region': 'North America',
#                                            'upc': '024294120688'}],
#                        'review_type': 'primary',
#                        'score': '6.8',
#                        'site_detail_url': 'https://www.gamespot.com/reviews/warhammer-shadow-of-the-horned-rat-review/1900-2531824/',
#                        'title': 'Warhammer: Shadow of the Horned Rat Review',
#                        'update_date': '1996-05-01 12:00:00'}],
#     'status_code': 1,
#     'version': '1.0'}
# 3

# %%
<div class="product_title">

# %%
urlr = 'https://www.metacritic.com/game/xbox-one/red-dead-redemption-2'
urlref = 'https://www.metacritic.com{}'.format(x)

# %%
response_soup = requests.get(urlr, headers = header)

# %%
soup = BeautifulSoup(response_soup.text, 'html.parser')

# %%
#print(soup.prettify())
## First go to website find what you want
## then keep going up in class until you find something with a unique title, grab that
my_prod_div = soup.findAll('div', {'class':"product_title"})

# now we have a much smaller section to look through and grab the piece of info we ashley care about
game_title = my_prod_div[0].h1.text
# Out:
# 'Red Dead Redemption 2'

# %%
# Out:
# No key found

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-85-7b1ecbd96128> in <module>
#       1 k = {}
# ----> 2 k['noone']
#
# KeyError: 'noone'
